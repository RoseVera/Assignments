# %%
import pandas as pd
import numpy as np
# Data Preparation
df = pd.read_csv('16p.csv', engine='python', encoding='cp1252')
df.drop(['Response Id'], axis = 1 , inplace = True)
df['Personality']=df['Personality'].replace({'ESTJ':0,'ENTJ': 1,'ESFJ': 2,'ENFJ' :3,'ISTJ' :4,'ISFJ' :5,'INTJ' :6,'INFJ' :7,'ESTP': 8,'ESFP': 9,'ENTP' :10,'ENFP': 11,'ISTP': 12,'ISFP': 13,'INTP' :14, 'INFP' :15})

#I split dependent and independent varibles
df_i = df.drop(['Personality'], axis=1) # Independent varibles
df_d = df['Personality'] # Dependent varibles

# Transform dataframe to numpy array
df_i_np = df_i.to_numpy()
df_d_np = df_d.to_numpy()

# I normalize Independent Data and assign this array to array named 'dfi'
dfi = (df_i_np+3)/6
print(dfi)
# Out:
# [[0.5        0.5        0.5        ... 0.5        0.5        0.5       ]
#  [0.5        0.5        0.16666667 ... 0.33333333 0.33333333 1.        ]
#  [0.5        0.5        0.83333333 ... 0.66666667 0.83333333 0.66666667]
#  ...
#  [0.5        0.5        0.66666667 ... 0.33333333 0.5        0.33333333]
#  [0.5        0.5        0.66666667 ... 0.5        0.66666667 0.5       ]
#  [0.5        0.5        0.83333333 ... 0.66666667 0.5        0.33333333]]

# %%
# I split the Dataset to train and test by ratio %80.
#train,test = np.split(dfi,[int(0.8 * len(dfi))]
train = dfi[:47999]                         
test= dfi[47999:]

# %%
train_class = df_d_np[:47999]                         
test_class = df_d_np[47999:]

# %%
print(len(train_class))
# Out:
# 47999

# %%
print(len(test_class))
# Out:
# 12000

# %%
def prediction(neighbors_list):
    prediction = max(set(neighbors_list), key=neighbors_list.count)
    return prediction

# %%
def KNN(train,test,k,train_class,test_class):
    # Calculating euclidian distance = sqrt(x-y)^2 = sqrt(x^2 -2xy + y^2)^2
    x_2 = np.sum(test**2, axis=1) 
    y_2 = np.sum(train**2, axis=1)
    xy = np.matmul(test, train.T)
    x_2 = x_2.reshape(-1, 1)
    distances = np.sqrt(x_2 - 2*xy + y_2)
    sorted_indices = np.argsort(distances)
    
    # Slicing array, total k indices 
    k_indices= sorted_indices[:,:k] 
    # Creating a confusion matrix
    con_mat=np.zeros((16,16))
    
    for i in range(len(test)):
        labels = train_class[k_indices[i]] # Take labels of k nearest neighbors.
        pred = prediction(list(labels)) # Making prediciton
        if pred != test_class[i]:
            con_mat[test_class[i]][pred]+=1
            print('Wrong Prediction',i+47999,'=> prediction:',pred,' real class:',test_class[i])
        else:
            con_mat[pred][pred]+=1 # I add to 1 value for every correct prediction to TP categhory.
            
    
    # ACCURACY
    sum_TP = 0
    sum_all = np.sum(con_mat)
    for x in range(16):
        sum_TP += con_mat[x][x] 
    accuracy = sum_TP/sum_all
    print('For K = ',k)
    print('accuracy:', accuracy)
    
    # PRECISSION AND RECALL
    precision, recall = 0,0
    # I calculate precision and recall for each class(0-15)
    for j in range(16):
        TP = con_mat[j][j]
        FP = np.sum(con_mat,axis=0)[j] - con_mat[j][j] # sum of all column - TP
        FN = np.sum(con_mat,axis=1)[j] - con_mat[j][j] # sum of all row - TP
    
        precision += TP / (TP + FP)
        recall += TP / (TP + FN )
        
    precision = precision/ 16 # For average precision
    recall = recall/ 16 # For average recall
    print('precision:', precision)
    print('recall:', recall)

# %%
KNN(train,test,5,train_class,test_class)
# Out:
# Wrong Prediction 48561 => prediction: 3  real class: 0
# Wrong Prediction 48727 => prediction: 13  real class: 14
# Wrong Prediction 48741 => prediction: 15  real class: 13
# Wrong Prediction 48957 => prediction: 14  real class: 9
# Wrong Prediction 49036 => prediction: 14  real class: 7
# Wrong Prediction 49244 => prediction: 14  real class: 9
# Wrong Prediction 49366 => prediction: 3  real class: 11
# Wrong Prediction 49416 => prediction: 7  real class: 3
# Wrong Prediction 49465 => prediction: 9  real class: 3
# Wrong Prediction 49486 => prediction: 2  real class: 7
# Wrong Prediction 49581 => prediction: 15  real class: 6
# Wrong Prediction 49615 => prediction: 3  real class: 2
# Wrong Prediction 49690 => prediction: 3  real class: 15
# Wrong Prediction 49960 => prediction: 4  real class: 15
# Wrong Prediction 49974 => prediction: 13  real class: 4
# Wrong Prediction 50044 => prediction: 15  real class: 4
# Wrong Prediction 50045 => prediction: 0  real class: 5
# Wrong Prediction 50170 => prediction: 5  real class: 14
# Wrong Prediction 50409 => prediction: 2  real class: 5
# Wrong Prediction 50513 => prediction: 1  real class: 15
# Wrong Prediction 50632 => prediction: 13  real class: 3
# Wrong Prediction 50758 => prediction: 3  real class: 5
# Wrong Prediction 50805 => prediction: 15  real class: 3
# Wrong Prediction 50881 => prediction: 1  real class: 10
# Wrong Prediction 50932 => prediction: 11  real class: 4
# Wrong Prediction 51047 => prediction: 9  real class: 15
# Wrong Prediction 51123 => prediction: 6  real class: 2
# Wrong Prediction 51234 => prediction: 9  real class: 2
# Wrong Prediction 51270 => prediction: 9  real class: 1
# Wrong Prediction 51342 => prediction: 9  real class: 13
# Wrong Prediction 51364 => prediction: 1  real class: 8
# Wrong Prediction 51385 => prediction: 9  real class: 7
# Wrong Prediction 51659 => prediction: 1  real class: 12
# Wrong Prediction 51692 => prediction: 14  real class: 2
# Wrong Prediction 51759 => prediction: 11  real class: 0
# Wrong Prediction 51833 => prediction: 8  real class: 5
# Wrong Prediction 51962 => prediction: 14  real class: 7
# Wrong Prediction 52062 => prediction: 0  real class: 4
# Wrong Prediction 52160 => prediction: 6  real class: 5
# Wrong Prediction 52278 => prediction: 2  real class: 12
# Wrong Prediction 52296 => prediction: 8  real class: 2
# Wrong Prediction 52595 => prediction: 4  real class: 5
# Wrong Prediction 52652 => prediction: 14  real class: 5
# Wrong Prediction 52764 => prediction: 14  real class: 2
# Wrong Prediction 52780 => prediction: 14  real class: 7
# Wrong Prediction 52784 => prediction: 5  real class: 9
# Wrong Prediction 52862 => prediction: 13  real class: 0
# Wrong Prediction 52934 => prediction: 6  real class: 8
# Wrong Prediction 52989 => prediction: 1  real class: 4
# Wrong Prediction 53007 => prediction: 15  real class: 10
# Wrong Prediction 53076 => prediction: 2  real class: 0
# Wrong Prediction 53077 => prediction: 8  real class: 15
# Wrong Prediction 53111 => prediction: 5  real class: 0
# Wrong Prediction 53112 => prediction: 8  real class: 6
# Wrong Prediction 53215 => prediction: 13  real class: 2
# Wrong Prediction 53252 => prediction: 8  real class: 9
# Wrong Prediction 53256 => prediction: 13  real class: 11
# Wrong Prediction 53279 => prediction: 11  real class: 2
# Wrong Prediction 53392 => prediction: 6  real class: 14
# Wrong Prediction 53475 => prediction: 14  real class: 3
# Wrong Prediction 53676 => prediction: 11  real class: 2
# Wrong Prediction 53761 => prediction: 4  real class: 15
# Wrong Prediction 53800 => prediction: 3  real class: 14
# Wrong Prediction 53896 => prediction: 13  real class: 7
# Wrong Prediction 53914 => prediction: 13  real class: 3
# Wrong Prediction 54062 => prediction: 11  real class: 4
# Wrong Prediction 54134 => prediction: 1  real class: 14
# Wrong Prediction 54151 => prediction: 5  real class: 11
# Wrong Prediction 54240 => prediction: 14  real class: 7
# Wrong Prediction 54254 => prediction: 14  real class: 1
# Wrong Prediction 54268 => prediction: 14  real class: 7
# Wrong Prediction 54550 => prediction: 3  real class: 12
# Wrong Prediction 54605 => prediction: 4  real class: 2
# Wrong Prediction 54645 => prediction: 11  real class: 13
# Wrong Prediction 54743 => prediction: 8  real class: 1
# Wrong Prediction 54849 => prediction: 1  real class: 2
# Wrong Prediction 54986 => prediction: 13  real class: 3
# Wrong Prediction 55084 => prediction: 15  real class: 13
# Wrong Prediction 55334 => prediction: 15  real class: 8
# Wrong Prediction 55399 => prediction: 7  real class: 6
# Wrong Prediction 55448 => prediction: 10  real class: 6
# Wrong Prediction 55489 => prediction: 7  real class: 1
# Wrong Prediction 55509 => prediction: 6  real class: 5
# Wrong Prediction 55512 => prediction: 10  real class: 11
# Wrong Prediction 55517 => prediction: 14  real class: 13
# Wrong Prediction 55526 => prediction: 3  real class: 5
# Wrong Prediction 55535 => prediction: 4  real class: 14
# Wrong Prediction 55536 => prediction: 1  real class: 0
# Wrong Prediction 55586 => prediction: 12  real class: 6
# Wrong Prediction 55614 => prediction: 9  real class: 1
# Wrong Prediction 55720 => prediction: 9  real class: 7
# Wrong Prediction 55846 => prediction: 14  real class: 3
# Wrong Prediction 55847 => prediction: 13  real class: 1
# Wrong Prediction 55858 => prediction: 14  real class: 10
# Wrong Prediction 56045 => prediction: 1  real class: 8
# Wrong Prediction 56222 => prediction: 2  real class: 0
# Wrong Prediction 56349 => prediction: 13  real class: 11
# Wrong Prediction 56354 => prediction: 14  real class: 4
# Wrong Prediction 56410 => prediction: 3  real class: 13
# Wrong Prediction 56566 => prediction: 9  real class: 2
# Wrong Prediction 56643 => prediction: 13  real class: 10
# Wrong Prediction 56801 => prediction: 11  real class: 7
# Wrong Prediction 56900 => prediction: 2  real class: 1
# Wrong Prediction 57007 => prediction: 3  real class: 1
# Wrong Prediction 57008 => prediction: 9  real class: 14
# Wrong Prediction 57267 => prediction: 12  real class: 10
# Wrong Prediction 57268 => prediction: 2  real class: 3
# Wrong Prediction 57286 => prediction: 13  real class: 12
# Wrong Prediction 57429 => prediction: 15  real class: 10
# Wrong Prediction 57481 => prediction: 7  real class: 9
# Wrong Prediction 57562 => prediction: 10  real class: 15
# Wrong Prediction 57649 => prediction: 13  real class: 9
# Wrong Prediction 57847 => prediction: 14  real class: 2
# Wrong Prediction 57902 => prediction: 15  real class: 1
# Wrong Prediction 58102 => prediction: 12  real class: 3
# Wrong Prediction 58157 => prediction: 5  real class: 7
# Wrong Prediction 58168 => prediction: 10  real class: 9
# Wrong Prediction 58393 => prediction: 1  real class: 15
# Wrong Prediction 58577 => prediction: 12  real class: 8
# Wrong Prediction 58587 => prediction: 1  real class: 9
# Wrong Prediction 58616 => prediction: 10  real class: 3
# Wrong Prediction 58652 => prediction: 11  real class: 4
# Wrong Prediction 58710 => prediction: 3  real class: 14
# Wrong Prediction 58804 => prediction: 15  real class: 0
# Wrong Prediction 58826 => prediction: 6  real class: 3
# Wrong Prediction 58891 => prediction: 6  real class: 11
# Wrong Prediction 58954 => prediction: 9  real class: 8
# Wrong Prediction 58998 => prediction: 6  real class: 7
# Wrong Prediction 59002 => prediction: 7  real class: 6
# Wrong Prediction 59086 => prediction: 2  real class: 6
# Wrong Prediction 59388 => prediction: 7  real class: 10
# Wrong Prediction 59413 => prediction: 5  real class: 9
# Wrong Prediction 59542 => prediction: 15  real class: 7
# Wrong Prediction 59560 => prediction: 13  real class: 10
# Wrong Prediction 59756 => prediction: 15  real class: 5
# Wrong Prediction 59946 => prediction: 14  real class: 0
# For K =  5
# accuracy: 0.9886666666666667
# precision: 0.988657383232201
# recall: 0.9886482340539449

# %%
KNN(train,test,1,train_class,test_class)
# Out:
# Wrong Prediction 48076 => prediction: 13  real class: 14
# Wrong Prediction 48082 => prediction: 9  real class: 11
# Wrong Prediction 48189 => prediction: 1  real class: 13
# Wrong Prediction 48207 => prediction: 8  real class: 12
# Wrong Prediction 48332 => prediction: 6  real class: 15
# Wrong Prediction 48391 => prediction: 2  real class: 6
# Wrong Prediction 48413 => prediction: 13  real class: 7
# Wrong Prediction 48439 => prediction: 3  real class: 13
# Wrong Prediction 48473 => prediction: 4  real class: 15
# Wrong Prediction 48561 => prediction: 3  real class: 0
# Wrong Prediction 48588 => prediction: 5  real class: 8
# Wrong Prediction 48727 => prediction: 13  real class: 14
# Wrong Prediction 48741 => prediction: 15  real class: 13
# Wrong Prediction 48812 => prediction: 15  real class: 0
# Wrong Prediction 48905 => prediction: 2  real class: 6
# Wrong Prediction 48957 => prediction: 14  real class: 9
# Wrong Prediction 49007 => prediction: 6  real class: 12
# Wrong Prediction 49009 => prediction: 5  real class: 0
# Wrong Prediction 49036 => prediction: 14  real class: 7
# Wrong Prediction 49187 => prediction: 4  real class: 15
# Wrong Prediction 49233 => prediction: 13  real class: 14
# Wrong Prediction 49239 => prediction: 11  real class: 13
# Wrong Prediction 49244 => prediction: 14  real class: 9
# Wrong Prediction 49366 => prediction: 3  real class: 11
# Wrong Prediction 49368 => prediction: 11  real class: 6
# Wrong Prediction 49416 => prediction: 7  real class: 3
# Wrong Prediction 49465 => prediction: 9  real class: 3
# Wrong Prediction 49486 => prediction: 2  real class: 7
# Wrong Prediction 49531 => prediction: 0  real class: 4
# Wrong Prediction 49581 => prediction: 15  real class: 6
# Wrong Prediction 49615 => prediction: 3  real class: 2
# Wrong Prediction 49690 => prediction: 3  real class: 15
# Wrong Prediction 49791 => prediction: 6  real class: 8
# Wrong Prediction 49806 => prediction: 7  real class: 15
# Wrong Prediction 49960 => prediction: 4  real class: 15
# Wrong Prediction 49974 => prediction: 13  real class: 4
# Wrong Prediction 50021 => prediction: 3  real class: 5
# Wrong Prediction 50114 => prediction: 15  real class: 13
# Wrong Prediction 50154 => prediction: 9  real class: 4
# Wrong Prediction 50170 => prediction: 5  real class: 14
# Wrong Prediction 50303 => prediction: 8  real class: 5
# Wrong Prediction 50338 => prediction: 6  real class: 13
# Wrong Prediction 50409 => prediction: 2  real class: 5
# Wrong Prediction 50447 => prediction: 4  real class: 0
# Wrong Prediction 50458 => prediction: 13  real class: 14
# Wrong Prediction 50498 => prediction: 12  real class: 2
# Wrong Prediction 50513 => prediction: 1  real class: 15
# Wrong Prediction 50552 => prediction: 5  real class: 12
# Wrong Prediction 50593 => prediction: 15  real class: 10
# Wrong Prediction 50615 => prediction: 6  real class: 10
# Wrong Prediction 50632 => prediction: 13  real class: 3
# Wrong Prediction 50758 => prediction: 3  real class: 5
# Wrong Prediction 50765 => prediction: 14  real class: 4
# Wrong Prediction 50786 => prediction: 15  real class: 10
# Wrong Prediction 50795 => prediction: 14  real class: 4
# Wrong Prediction 50805 => prediction: 15  real class: 3
# Wrong Prediction 50881 => prediction: 1  real class: 10
# Wrong Prediction 50932 => prediction: 11  real class: 4
# Wrong Prediction 51031 => prediction: 14  real class: 6
# Wrong Prediction 51047 => prediction: 9  real class: 15
# Wrong Prediction 51123 => prediction: 6  real class: 2
# Wrong Prediction 51153 => prediction: 11  real class: 14
# Wrong Prediction 51155 => prediction: 10  real class: 4
# Wrong Prediction 51207 => prediction: 1  real class: 14
# Wrong Prediction 51212 => prediction: 5  real class: 9
# Wrong Prediction 51234 => prediction: 9  real class: 2
# Wrong Prediction 51270 => prediction: 9  real class: 1
# Wrong Prediction 51277 => prediction: 4  real class: 1
# Wrong Prediction 51342 => prediction: 9  real class: 13
# Wrong Prediction 51364 => prediction: 1  real class: 8
# Wrong Prediction 51385 => prediction: 9  real class: 7
# Wrong Prediction 51484 => prediction: 6  real class: 15
# Wrong Prediction 51542 => prediction: 8  real class: 2
# Wrong Prediction 51543 => prediction: 12  real class: 8
# Wrong Prediction 51659 => prediction: 1  real class: 12
# Wrong Prediction 51692 => prediction: 14  real class: 2
# Wrong Prediction 51723 => prediction: 6  real class: 14
# Wrong Prediction 51759 => prediction: 11  real class: 0
# Wrong Prediction 51765 => prediction: 13  real class: 5
# Wrong Prediction 51833 => prediction: 8  real class: 5
# Wrong Prediction 51941 => prediction: 4  real class: 12
# Wrong Prediction 51962 => prediction: 14  real class: 7
# Wrong Prediction 52062 => prediction: 0  real class: 4
# Wrong Prediction 52160 => prediction: 6  real class: 5
# Wrong Prediction 52278 => prediction: 2  real class: 12
# Wrong Prediction 52296 => prediction: 8  real class: 2
# Wrong Prediction 52306 => prediction: 8  real class: 7
# Wrong Prediction 52541 => prediction: 14  real class: 4
# Wrong Prediction 52595 => prediction: 4  real class: 5
# Wrong Prediction 52623 => prediction: 9  real class: 11
# Wrong Prediction 52631 => prediction: 2  real class: 8
# Wrong Prediction 52652 => prediction: 14  real class: 5
# Wrong Prediction 52715 => prediction: 0  real class: 8
# Wrong Prediction 52764 => prediction: 14  real class: 2
# Wrong Prediction 52782 => prediction: 1  real class: 13
# Wrong Prediction 52784 => prediction: 5  real class: 9
# Wrong Prediction 52862 => prediction: 13  real class: 0
# Wrong Prediction 52925 => prediction: 11  real class: 7
# Wrong Prediction 52931 => prediction: 14  real class: 11
# Wrong Prediction 52989 => prediction: 1  real class: 4
# Wrong Prediction 53007 => prediction: 15  real class: 10
# Wrong Prediction 53076 => prediction: 2  real class: 0
# Wrong Prediction 53077 => prediction: 8  real class: 15
# Wrong Prediction 53101 => prediction: 7  real class: 1
# Wrong Prediction 53111 => prediction: 5  real class: 0
# Wrong Prediction 53112 => prediction: 8  real class: 6
# Wrong Prediction 53215 => prediction: 13  real class: 2
# Wrong Prediction 53256 => prediction: 13  real class: 11
# Wrong Prediction 53279 => prediction: 11  real class: 2
# Wrong Prediction 53389 => prediction: 5  real class: 8
# Wrong Prediction 53392 => prediction: 6  real class: 14
# Wrong Prediction 53475 => prediction: 14  real class: 3
# Wrong Prediction 53495 => prediction: 0  real class: 10
# Wrong Prediction 53568 => prediction: 1  real class: 3
# Wrong Prediction 53676 => prediction: 11  real class: 2
# Wrong Prediction 53761 => prediction: 4  real class: 15
# Wrong Prediction 53800 => prediction: 3  real class: 14
# Wrong Prediction 53831 => prediction: 10  real class: 15
# Wrong Prediction 53896 => prediction: 13  real class: 7
# Wrong Prediction 53914 => prediction: 13  real class: 3
# Wrong Prediction 53942 => prediction: 13  real class: 12
# Wrong Prediction 53975 => prediction: 14  real class: 1
# Wrong Prediction 54043 => prediction: 11  real class: 6
# Wrong Prediction 54062 => prediction: 11  real class: 4
# Wrong Prediction 54095 => prediction: 6  real class: 12
# Wrong Prediction 54134 => prediction: 1  real class: 14
# Wrong Prediction 54151 => prediction: 5  real class: 11
# Wrong Prediction 54156 => prediction: 12  real class: 2
# Wrong Prediction 54171 => prediction: 6  real class: 5
# Wrong Prediction 54177 => prediction: 3  real class: 5
# Wrong Prediction 54217 => prediction: 12  real class: 6
# Wrong Prediction 54240 => prediction: 14  real class: 7
# Wrong Prediction 54254 => prediction: 14  real class: 1
# Wrong Prediction 54268 => prediction: 14  real class: 7
# Wrong Prediction 54320 => prediction: 3  real class: 14
# Wrong Prediction 54369 => prediction: 6  real class: 13
# Wrong Prediction 54428 => prediction: 3  real class: 10
# Wrong Prediction 54443 => prediction: 12  real class: 5
# Wrong Prediction 54510 => prediction: 10  real class: 15
# Wrong Prediction 54550 => prediction: 3  real class: 12
# Wrong Prediction 54584 => prediction: 12  real class: 5
# Wrong Prediction 54605 => prediction: 14  real class: 2
# Wrong Prediction 54625 => prediction: 4  real class: 14
# Wrong Prediction 54645 => prediction: 11  real class: 13
# Wrong Prediction 54743 => prediction: 8  real class: 1
# Wrong Prediction 54762 => prediction: 15  real class: 2
# Wrong Prediction 54849 => prediction: 1  real class: 2
# Wrong Prediction 54863 => prediction: 13  real class: 3
# Wrong Prediction 54986 => prediction: 13  real class: 3
# Wrong Prediction 55084 => prediction: 15  real class: 13
# Wrong Prediction 55272 => prediction: 4  real class: 15
# Wrong Prediction 55366 => prediction: 15  real class: 10
# Wrong Prediction 55390 => prediction: 14  real class: 5
# Wrong Prediction 55399 => prediction: 7  real class: 6
# Wrong Prediction 55430 => prediction: 12  real class: 2
# Wrong Prediction 55448 => prediction: 10  real class: 6
# Wrong Prediction 55489 => prediction: 7  real class: 1
# Wrong Prediction 55509 => prediction: 6  real class: 5
# Wrong Prediction 55512 => prediction: 10  real class: 11
# Wrong Prediction 55517 => prediction: 14  real class: 13
# Wrong Prediction 55526 => prediction: 15  real class: 5
# Wrong Prediction 55535 => prediction: 4  real class: 14
# Wrong Prediction 55536 => prediction: 1  real class: 0
# Wrong Prediction 55586 => prediction: 12  real class: 6
# Wrong Prediction 55614 => prediction: 9  real class: 1
# Wrong Prediction 55649 => prediction: 11  real class: 13
# Wrong Prediction 55720 => prediction: 9  real class: 7
# Wrong Prediction 55743 => prediction: 11  real class: 3
# Wrong Prediction 55799 => prediction: 6  real class: 8
# Wrong Prediction 55839 => prediction: 8  real class: 5
# Wrong Prediction 55846 => prediction: 14  real class: 3
# Wrong Prediction 55847 => prediction: 13  real class: 1
# Wrong Prediction 55858 => prediction: 14  real class: 10
# Wrong Prediction 56045 => prediction: 1  real class: 8
# Wrong Prediction 56048 => prediction: 1  real class: 13
# Wrong Prediction 56222 => prediction: 2  real class: 0
# Wrong Prediction 56244 => prediction: 6  real class: 10
# Wrong Prediction 56289 => prediction: 13  real class: 11
# Wrong Prediction 56302 => prediction: 14  real class: 5
# Wrong Prediction 56349 => prediction: 13  real class: 11
# Wrong Prediction 56391 => prediction: 11  real class: 2
# Wrong Prediction 56410 => prediction: 3  real class: 13
# Wrong Prediction 56440 => prediction: 12  real class: 4
# Wrong Prediction 56566 => prediction: 9  real class: 2
# Wrong Prediction 56631 => prediction: 0  real class: 11
# Wrong Prediction 56635 => prediction: 8  real class: 9
# Wrong Prediction 56643 => prediction: 13  real class: 10
# Wrong Prediction 56714 => prediction: 5  real class: 6
# Wrong Prediction 56735 => prediction: 2  real class: 14
# Wrong Prediction 56801 => prediction: 11  real class: 7
# Wrong Prediction 56900 => prediction: 2  real class: 1
# Wrong Prediction 56906 => prediction: 14  real class: 4
# Wrong Prediction 56938 => prediction: 11  real class: 4
# Wrong Prediction 56965 => prediction: 1  real class: 7
# Wrong Prediction 56982 => prediction: 13  real class: 8
# Wrong Prediction 57007 => prediction: 3  real class: 1
# Wrong Prediction 57008 => prediction: 9  real class: 14
# Wrong Prediction 57074 => prediction: 11  real class: 14
# Wrong Prediction 57137 => prediction: 2  real class: 9
# Wrong Prediction 57267 => prediction: 12  real class: 10
# Wrong Prediction 57268 => prediction: 2  real class: 3
# Wrong Prediction 57286 => prediction: 13  real class: 12
# Wrong Prediction 57299 => prediction: 15  real class: 0
# Wrong Prediction 57319 => prediction: 3  real class: 13
# Wrong Prediction 57393 => prediction: 5  real class: 10
# Wrong Prediction 57415 => prediction: 5  real class: 12
# Wrong Prediction 57429 => prediction: 15  real class: 10
# Wrong Prediction 57481 => prediction: 7  real class: 9
# Wrong Prediction 57561 => prediction: 4  real class: 15
# Wrong Prediction 57562 => prediction: 10  real class: 15
# Wrong Prediction 57649 => prediction: 13  real class: 9
# Wrong Prediction 57723 => prediction: 8  real class: 15
# Wrong Prediction 57847 => prediction: 14  real class: 2
# Wrong Prediction 57885 => prediction: 4  real class: 6
# Wrong Prediction 57898 => prediction: 9  real class: 6
# Wrong Prediction 57902 => prediction: 15  real class: 1
# Wrong Prediction 57943 => prediction: 1  real class: 13
# Wrong Prediction 57989 => prediction: 10  real class: 2
# Wrong Prediction 58073 => prediction: 8  real class: 6
# Wrong Prediction 58102 => prediction: 12  real class: 3
# Wrong Prediction 58157 => prediction: 5  real class: 7
# Wrong Prediction 58162 => prediction: 2  real class: 6
# Wrong Prediction 58168 => prediction: 10  real class: 9
# Wrong Prediction 58205 => prediction: 4  real class: 15
# Wrong Prediction 58217 => prediction: 1  real class: 13
# Wrong Prediction 58393 => prediction: 1  real class: 15
# Wrong Prediction 58410 => prediction: 0  real class: 13
# Wrong Prediction 58421 => prediction: 9  real class: 13
# Wrong Prediction 58454 => prediction: 13  real class: 15
# Wrong Prediction 58458 => prediction: 0  real class: 10
# Wrong Prediction 58531 => prediction: 12  real class: 6
# Wrong Prediction 58577 => prediction: 12  real class: 8
# Wrong Prediction 58587 => prediction: 1  real class: 9
# Wrong Prediction 58604 => prediction: 6  real class: 15
# Wrong Prediction 58616 => prediction: 10  real class: 3
# Wrong Prediction 58652 => prediction: 11  real class: 4
# Wrong Prediction 58710 => prediction: 3  real class: 14
# Wrong Prediction 58804 => prediction: 15  real class: 0
# Wrong Prediction 58826 => prediction: 6  real class: 3
# Wrong Prediction 58891 => prediction: 6  real class: 11
# Wrong Prediction 58954 => prediction: 9  real class: 8
# Wrong Prediction 58998 => prediction: 6  real class: 7
# Wrong Prediction 59002 => prediction: 7  real class: 6
# Wrong Prediction 59012 => prediction: 6  real class: 15
# Wrong Prediction 59064 => prediction: 3  real class: 12
# Wrong Prediction 59086 => prediction: 2  real class: 6
# Wrong Prediction 59141 => prediction: 15  real class: 14
# Wrong Prediction 59235 => prediction: 11  real class: 3
# Wrong Prediction 59284 => prediction: 7  real class: 14
# Wrong Prediction 59311 => prediction: 15  real class: 1
# Wrong Prediction 59388 => prediction: 7  real class: 10
# Wrong Prediction 59413 => prediction: 5  real class: 9
# Wrong Prediction 59527 => prediction: 8  real class: 5
# Wrong Prediction 59542 => prediction: 15  real class: 7
# Wrong Prediction 59560 => prediction: 13  real class: 10
# Wrong Prediction 59591 => prediction: 14  real class: 8
# Wrong Prediction 59640 => prediction: 11  real class: 6
# Wrong Prediction 59756 => prediction: 15  real class: 5
# Wrong Prediction 59850 => prediction: 7  real class: 14
# Wrong Prediction 59946 => prediction: 14  real class: 0
# For K =  1
# accuracy: 0.9783333333333334
# precision: 0.9783042430177052
# recall: 0.9782880233852064

# %%
KNN(train,test,3,train_class,test_class)
# Out:
# Wrong Prediction 48391 => prediction: 2  real class: 6
# Wrong Prediction 48413 => prediction: 13  real class: 7
# Wrong Prediction 48561 => prediction: 3  real class: 0
# Wrong Prediction 48727 => prediction: 13  real class: 14
# Wrong Prediction 48741 => prediction: 15  real class: 13
# Wrong Prediction 48957 => prediction: 14  real class: 9
# Wrong Prediction 49036 => prediction: 14  real class: 7
# Wrong Prediction 49244 => prediction: 14  real class: 9
# Wrong Prediction 49366 => prediction: 3  real class: 11
# Wrong Prediction 49416 => prediction: 7  real class: 3
# Wrong Prediction 49465 => prediction: 9  real class: 3
# Wrong Prediction 49486 => prediction: 2  real class: 7
# Wrong Prediction 49581 => prediction: 15  real class: 6
# Wrong Prediction 49615 => prediction: 3  real class: 2
# Wrong Prediction 49690 => prediction: 3  real class: 15
# Wrong Prediction 49960 => prediction: 4  real class: 15
# Wrong Prediction 49974 => prediction: 13  real class: 4
# Wrong Prediction 50044 => prediction: 15  real class: 4
# Wrong Prediction 50170 => prediction: 5  real class: 14
# Wrong Prediction 50409 => prediction: 2  real class: 5
# Wrong Prediction 50513 => prediction: 1  real class: 15
# Wrong Prediction 50632 => prediction: 13  real class: 3
# Wrong Prediction 50758 => prediction: 3  real class: 5
# Wrong Prediction 50805 => prediction: 15  real class: 3
# Wrong Prediction 50881 => prediction: 1  real class: 10
# Wrong Prediction 50932 => prediction: 11  real class: 4
# Wrong Prediction 51047 => prediction: 9  real class: 15
# Wrong Prediction 51123 => prediction: 6  real class: 2
# Wrong Prediction 51234 => prediction: 9  real class: 2
# Wrong Prediction 51270 => prediction: 9  real class: 1
# Wrong Prediction 51342 => prediction: 9  real class: 13
# Wrong Prediction 51364 => prediction: 1  real class: 8
# Wrong Prediction 51385 => prediction: 9  real class: 7
# Wrong Prediction 51659 => prediction: 1  real class: 12
# Wrong Prediction 51692 => prediction: 14  real class: 2
# Wrong Prediction 51759 => prediction: 11  real class: 0
# Wrong Prediction 51833 => prediction: 8  real class: 5
# Wrong Prediction 51962 => prediction: 14  real class: 7
# Wrong Prediction 52062 => prediction: 0  real class: 4
# Wrong Prediction 52160 => prediction: 6  real class: 5
# Wrong Prediction 52278 => prediction: 2  real class: 12
# Wrong Prediction 52296 => prediction: 8  real class: 2
# Wrong Prediction 52595 => prediction: 4  real class: 5
# Wrong Prediction 52652 => prediction: 14  real class: 5
# Wrong Prediction 52764 => prediction: 14  real class: 2
# Wrong Prediction 52780 => prediction: 14  real class: 7
# Wrong Prediction 52784 => prediction: 5  real class: 9
# Wrong Prediction 52862 => prediction: 13  real class: 0
# Wrong Prediction 52989 => prediction: 1  real class: 4
# Wrong Prediction 53007 => prediction: 15  real class: 10
# Wrong Prediction 53056 => prediction: 11  real class: 14
# Wrong Prediction 53076 => prediction: 2  real class: 0
# Wrong Prediction 53077 => prediction: 8  real class: 15
# Wrong Prediction 53111 => prediction: 5  real class: 0
# Wrong Prediction 53112 => prediction: 8  real class: 6
# Wrong Prediction 53215 => prediction: 13  real class: 2
# Wrong Prediction 53256 => prediction: 13  real class: 11
# Wrong Prediction 53279 => prediction: 11  real class: 2
# Wrong Prediction 53392 => prediction: 6  real class: 14
# Wrong Prediction 53475 => prediction: 14  real class: 3
# Wrong Prediction 53676 => prediction: 11  real class: 2
# Wrong Prediction 53761 => prediction: 4  real class: 15
# Wrong Prediction 53800 => prediction: 3  real class: 14
# Wrong Prediction 53896 => prediction: 4  real class: 7
# Wrong Prediction 53914 => prediction: 13  real class: 3
# Wrong Prediction 54062 => prediction: 11  real class: 4
# Wrong Prediction 54134 => prediction: 1  real class: 14
# Wrong Prediction 54151 => prediction: 5  real class: 11
# Wrong Prediction 54171 => prediction: 12  real class: 5
# Wrong Prediction 54240 => prediction: 14  real class: 7
# Wrong Prediction 54254 => prediction: 14  real class: 1
# Wrong Prediction 54268 => prediction: 14  real class: 7
# Wrong Prediction 54320 => prediction: 2  real class: 14
# Wrong Prediction 54550 => prediction: 3  real class: 12
# Wrong Prediction 54605 => prediction: 4  real class: 2
# Wrong Prediction 54645 => prediction: 11  real class: 13
# Wrong Prediction 54743 => prediction: 8  real class: 1
# Wrong Prediction 54849 => prediction: 1  real class: 2
# Wrong Prediction 54863 => prediction: 5  real class: 3
# Wrong Prediction 54986 => prediction: 13  real class: 3
# Wrong Prediction 55084 => prediction: 15  real class: 13
# Wrong Prediction 55399 => prediction: 7  real class: 6
# Wrong Prediction 55448 => prediction: 10  real class: 6
# Wrong Prediction 55489 => prediction: 7  real class: 1
# Wrong Prediction 55509 => prediction: 6  real class: 5
# Wrong Prediction 55512 => prediction: 10  real class: 11
# Wrong Prediction 55517 => prediction: 14  real class: 13
# Wrong Prediction 55526 => prediction: 3  real class: 5
# Wrong Prediction 55535 => prediction: 4  real class: 14
# Wrong Prediction 55536 => prediction: 1  real class: 0
# Wrong Prediction 55586 => prediction: 12  real class: 6
# Wrong Prediction 55614 => prediction: 9  real class: 1
# Wrong Prediction 55720 => prediction: 9  real class: 7
# Wrong Prediction 55846 => prediction: 14  real class: 3
# Wrong Prediction 55847 => prediction: 13  real class: 1
# Wrong Prediction 55858 => prediction: 14  real class: 10
# Wrong Prediction 56045 => prediction: 1  real class: 8
# Wrong Prediction 56222 => prediction: 2  real class: 0
# Wrong Prediction 56349 => prediction: 13  real class: 11
# Wrong Prediction 56410 => prediction: 3  real class: 13
# Wrong Prediction 56566 => prediction: 9  real class: 2
# Wrong Prediction 56643 => prediction: 13  real class: 10
# Wrong Prediction 56735 => prediction: 2  real class: 14
# Wrong Prediction 56801 => prediction: 11  real class: 7
# Wrong Prediction 56900 => prediction: 2  real class: 1
# Wrong Prediction 57007 => prediction: 3  real class: 1
# Wrong Prediction 57008 => prediction: 9  real class: 14
# Wrong Prediction 57137 => prediction: 2  real class: 9
# Wrong Prediction 57267 => prediction: 12  real class: 10
# Wrong Prediction 57268 => prediction: 2  real class: 3
# Wrong Prediction 57286 => prediction: 13  real class: 12
# Wrong Prediction 57429 => prediction: 15  real class: 10
# Wrong Prediction 57481 => prediction: 7  real class: 9
# Wrong Prediction 57562 => prediction: 10  real class: 15
# Wrong Prediction 57649 => prediction: 13  real class: 9
# Wrong Prediction 57843 => prediction: 5  real class: 13
# Wrong Prediction 57847 => prediction: 14  real class: 2
# Wrong Prediction 57902 => prediction: 15  real class: 1
# Wrong Prediction 57943 => prediction: 1  real class: 13
# Wrong Prediction 57989 => prediction: 10  real class: 2
# Wrong Prediction 58102 => prediction: 12  real class: 3
# Wrong Prediction 58157 => prediction: 5  real class: 7
# Wrong Prediction 58168 => prediction: 10  real class: 9
# Wrong Prediction 58393 => prediction: 1  real class: 15
# Wrong Prediction 58577 => prediction: 12  real class: 8
# Wrong Prediction 58587 => prediction: 1  real class: 9
# Wrong Prediction 58616 => prediction: 10  real class: 3
# Wrong Prediction 58652 => prediction: 11  real class: 4
# Wrong Prediction 58710 => prediction: 3  real class: 14
# Wrong Prediction 58804 => prediction: 15  real class: 0
# Wrong Prediction 58826 => prediction: 6  real class: 3
# Wrong Prediction 58891 => prediction: 6  real class: 11
# Wrong Prediction 58954 => prediction: 9  real class: 8
# Wrong Prediction 58998 => prediction: 6  real class: 7
# Wrong Prediction 59002 => prediction: 7  real class: 6
# Wrong Prediction 59086 => prediction: 2  real class: 6
# Wrong Prediction 59388 => prediction: 7  real class: 10
# Wrong Prediction 59413 => prediction: 5  real class: 9
# Wrong Prediction 59542 => prediction: 15  real class: 7
# Wrong Prediction 59560 => prediction: 13  real class: 10
# Wrong Prediction 59756 => prediction: 15  real class: 5
# Wrong Prediction 59946 => prediction: 14  real class: 0
# For K =  3
# accuracy: 0.9881666666666666
# precision: 0.9881548465514688
# recall: 0.9881313372472769

# %%
KNN(train,test,7,train_class,test_class)
# Out:
# Wrong Prediction 48561 => prediction: 3  real class: 0
# Wrong Prediction 48727 => prediction: 13  real class: 14
# Wrong Prediction 48741 => prediction: 15  real class: 13
# Wrong Prediction 48957 => prediction: 14  real class: 9
# Wrong Prediction 49036 => prediction: 14  real class: 7
# Wrong Prediction 49244 => prediction: 14  real class: 9
# Wrong Prediction 49366 => prediction: 3  real class: 11
# Wrong Prediction 49416 => prediction: 7  real class: 3
# Wrong Prediction 49465 => prediction: 9  real class: 3
# Wrong Prediction 49486 => prediction: 2  real class: 7
# Wrong Prediction 49581 => prediction: 15  real class: 6
# Wrong Prediction 49615 => prediction: 3  real class: 2
# Wrong Prediction 49690 => prediction: 3  real class: 15
# Wrong Prediction 49960 => prediction: 4  real class: 15
# Wrong Prediction 49974 => prediction: 13  real class: 4
# Wrong Prediction 50044 => prediction: 15  real class: 4
# Wrong Prediction 50170 => prediction: 5  real class: 14
# Wrong Prediction 50409 => prediction: 2  real class: 5
# Wrong Prediction 50513 => prediction: 1  real class: 15
# Wrong Prediction 50600 => prediction: 11  real class: 12
# Wrong Prediction 50632 => prediction: 13  real class: 3
# Wrong Prediction 50758 => prediction: 3  real class: 5
# Wrong Prediction 50805 => prediction: 15  real class: 3
# Wrong Prediction 50881 => prediction: 1  real class: 10
# Wrong Prediction 50932 => prediction: 11  real class: 4
# Wrong Prediction 51047 => prediction: 9  real class: 15
# Wrong Prediction 51123 => prediction: 6  real class: 2
# Wrong Prediction 51234 => prediction: 9  real class: 2
# Wrong Prediction 51270 => prediction: 9  real class: 1
# Wrong Prediction 51342 => prediction: 9  real class: 13
# Wrong Prediction 51364 => prediction: 1  real class: 8
# Wrong Prediction 51385 => prediction: 9  real class: 7
# Wrong Prediction 51659 => prediction: 1  real class: 12
# Wrong Prediction 51692 => prediction: 14  real class: 2
# Wrong Prediction 51759 => prediction: 11  real class: 0
# Wrong Prediction 51833 => prediction: 8  real class: 5
# Wrong Prediction 51962 => prediction: 14  real class: 7
# Wrong Prediction 52062 => prediction: 0  real class: 4
# Wrong Prediction 52160 => prediction: 6  real class: 5
# Wrong Prediction 52278 => prediction: 2  real class: 12
# Wrong Prediction 52296 => prediction: 8  real class: 2
# Wrong Prediction 52595 => prediction: 4  real class: 5
# Wrong Prediction 52652 => prediction: 14  real class: 5
# Wrong Prediction 52764 => prediction: 14  real class: 2
# Wrong Prediction 52780 => prediction: 14  real class: 7
# Wrong Prediction 52784 => prediction: 5  real class: 9
# Wrong Prediction 52862 => prediction: 13  real class: 0
# Wrong Prediction 52989 => prediction: 1  real class: 4
# Wrong Prediction 53007 => prediction: 15  real class: 10
# Wrong Prediction 53076 => prediction: 2  real class: 0
# Wrong Prediction 53077 => prediction: 8  real class: 15
# Wrong Prediction 53111 => prediction: 5  real class: 0
# Wrong Prediction 53112 => prediction: 8  real class: 6
# Wrong Prediction 53215 => prediction: 13  real class: 2
# Wrong Prediction 53252 => prediction: 7  real class: 9
# Wrong Prediction 53256 => prediction: 13  real class: 11
# Wrong Prediction 53279 => prediction: 11  real class: 2
# Wrong Prediction 53392 => prediction: 6  real class: 14
# Wrong Prediction 53475 => prediction: 14  real class: 3
# Wrong Prediction 53676 => prediction: 11  real class: 2
# Wrong Prediction 53761 => prediction: 4  real class: 15
# Wrong Prediction 53800 => prediction: 3  real class: 14
# Wrong Prediction 53914 => prediction: 13  real class: 3
# Wrong Prediction 54062 => prediction: 11  real class: 4
# Wrong Prediction 54134 => prediction: 1  real class: 14
# Wrong Prediction 54151 => prediction: 5  real class: 11
# Wrong Prediction 54240 => prediction: 14  real class: 7
# Wrong Prediction 54254 => prediction: 14  real class: 1
# Wrong Prediction 54268 => prediction: 14  real class: 7
# Wrong Prediction 54550 => prediction: 3  real class: 12
# Wrong Prediction 54605 => prediction: 4  real class: 2
# Wrong Prediction 54645 => prediction: 11  real class: 13
# Wrong Prediction 54743 => prediction: 8  real class: 1
# Wrong Prediction 54849 => prediction: 1  real class: 2
# Wrong Prediction 54986 => prediction: 13  real class: 3
# Wrong Prediction 55084 => prediction: 15  real class: 13
# Wrong Prediction 55399 => prediction: 7  real class: 6
# Wrong Prediction 55448 => prediction: 10  real class: 6
# Wrong Prediction 55489 => prediction: 7  real class: 1
# Wrong Prediction 55509 => prediction: 6  real class: 5
# Wrong Prediction 55512 => prediction: 10  real class: 11
# Wrong Prediction 55517 => prediction: 14  real class: 13
# Wrong Prediction 55526 => prediction: 3  real class: 5
# Wrong Prediction 55535 => prediction: 4  real class: 14
# Wrong Prediction 55536 => prediction: 1  real class: 0
# Wrong Prediction 55586 => prediction: 12  real class: 6
# Wrong Prediction 55614 => prediction: 9  real class: 1
# Wrong Prediction 55720 => prediction: 9  real class: 7
# Wrong Prediction 55846 => prediction: 14  real class: 3
# Wrong Prediction 55847 => prediction: 13  real class: 1
# Wrong Prediction 55858 => prediction: 14  real class: 10
# Wrong Prediction 56045 => prediction: 1  real class: 8
# Wrong Prediction 56222 => prediction: 2  real class: 0
# Wrong Prediction 56349 => prediction: 13  real class: 11
# Wrong Prediction 56410 => prediction: 3  real class: 13
# Wrong Prediction 56423 => prediction: 8  real class: 4
# Wrong Prediction 56566 => prediction: 9  real class: 2
# Wrong Prediction 56643 => prediction: 13  real class: 10
# Wrong Prediction 56801 => prediction: 11  real class: 7
# Wrong Prediction 56900 => prediction: 2  real class: 1
# Wrong Prediction 57007 => prediction: 3  real class: 1
# Wrong Prediction 57008 => prediction: 9  real class: 14
# Wrong Prediction 57267 => prediction: 12  real class: 10
# Wrong Prediction 57268 => prediction: 2  real class: 3
# Wrong Prediction 57286 => prediction: 13  real class: 12
# Wrong Prediction 57429 => prediction: 15  real class: 10
# Wrong Prediction 57481 => prediction: 7  real class: 9
# Wrong Prediction 57562 => prediction: 10  real class: 15
# Wrong Prediction 57649 => prediction: 13  real class: 9
# Wrong Prediction 57847 => prediction: 14  real class: 2
# Wrong Prediction 57902 => prediction: 15  real class: 1
# Wrong Prediction 58102 => prediction: 12  real class: 3
# Wrong Prediction 58157 => prediction: 5  real class: 7
# Wrong Prediction 58168 => prediction: 10  real class: 9
# Wrong Prediction 58393 => prediction: 1  real class: 15
# Wrong Prediction 58577 => prediction: 12  real class: 8
# Wrong Prediction 58587 => prediction: 1  real class: 9
# Wrong Prediction 58616 => prediction: 10  real class: 3
# Wrong Prediction 58652 => prediction: 11  real class: 4
# Wrong Prediction 58710 => prediction: 3  real class: 14
# Wrong Prediction 58804 => prediction: 15  real class: 0
# Wrong Prediction 58826 => prediction: 6  real class: 3
# Wrong Prediction 58891 => prediction: 6  real class: 11
# Wrong Prediction 58954 => prediction: 9  real class: 8
# Wrong Prediction 58998 => prediction: 6  real class: 7
# Wrong Prediction 59002 => prediction: 7  real class: 6
# Wrong Prediction 59388 => prediction: 7  real class: 10
# Wrong Prediction 59413 => prediction: 5  real class: 9
# Wrong Prediction 59542 => prediction: 15  real class: 7
# Wrong Prediction 59560 => prediction: 13  real class: 10
# Wrong Prediction 59756 => prediction: 15  real class: 5
# Wrong Prediction 59946 => prediction: 14  real class: 0
# For K =  7
# accuracy: 0.989
# precision: 0.9889925343654058
# recall: 0.988983661350532

# %%
KNN(train,test,9,train_class,test_class)
# Out:
# Wrong Prediction 48561 => prediction: 3  real class: 0
# Wrong Prediction 48727 => prediction: 13  real class: 14
# Wrong Prediction 48741 => prediction: 15  real class: 13
# Wrong Prediction 48957 => prediction: 14  real class: 9
# Wrong Prediction 49036 => prediction: 14  real class: 7
# Wrong Prediction 49244 => prediction: 14  real class: 9
# Wrong Prediction 49366 => prediction: 3  real class: 11
# Wrong Prediction 49416 => prediction: 7  real class: 3
# Wrong Prediction 49465 => prediction: 9  real class: 3
# Wrong Prediction 49486 => prediction: 2  real class: 7
# Wrong Prediction 49581 => prediction: 15  real class: 6
# Wrong Prediction 49615 => prediction: 3  real class: 2
# Wrong Prediction 49690 => prediction: 3  real class: 15
# Wrong Prediction 49960 => prediction: 4  real class: 15
# Wrong Prediction 49974 => prediction: 13  real class: 4
# Wrong Prediction 50044 => prediction: 15  real class: 4
# Wrong Prediction 50170 => prediction: 5  real class: 14
# Wrong Prediction 50409 => prediction: 2  real class: 5
# Wrong Prediction 50513 => prediction: 1  real class: 15
# Wrong Prediction 50632 => prediction: 13  real class: 3
# Wrong Prediction 50758 => prediction: 3  real class: 5
# Wrong Prediction 50805 => prediction: 15  real class: 3
# Wrong Prediction 50881 => prediction: 1  real class: 10
# Wrong Prediction 50932 => prediction: 11  real class: 4
# Wrong Prediction 51047 => prediction: 9  real class: 15
# Wrong Prediction 51123 => prediction: 6  real class: 2
# Wrong Prediction 51234 => prediction: 9  real class: 2
# Wrong Prediction 51270 => prediction: 9  real class: 1
# Wrong Prediction 51342 => prediction: 9  real class: 13
# Wrong Prediction 51364 => prediction: 1  real class: 8
# Wrong Prediction 51385 => prediction: 9  real class: 7
# Wrong Prediction 51659 => prediction: 1  real class: 12
# Wrong Prediction 51692 => prediction: 14  real class: 2
# Wrong Prediction 51759 => prediction: 11  real class: 0
# Wrong Prediction 51833 => prediction: 8  real class: 5
# Wrong Prediction 51962 => prediction: 14  real class: 7
# Wrong Prediction 52062 => prediction: 0  real class: 4
# Wrong Prediction 52160 => prediction: 6  real class: 5
# Wrong Prediction 52278 => prediction: 2  real class: 12
# Wrong Prediction 52296 => prediction: 8  real class: 2
# Wrong Prediction 52595 => prediction: 4  real class: 5
# Wrong Prediction 52652 => prediction: 14  real class: 5
# Wrong Prediction 52764 => prediction: 14  real class: 2
# Wrong Prediction 52780 => prediction: 14  real class: 7
# Wrong Prediction 52784 => prediction: 5  real class: 9
# Wrong Prediction 52862 => prediction: 13  real class: 0
# Wrong Prediction 52989 => prediction: 1  real class: 4
# Wrong Prediction 53007 => prediction: 15  real class: 10
# Wrong Prediction 53076 => prediction: 2  real class: 0
# Wrong Prediction 53077 => prediction: 8  real class: 15
# Wrong Prediction 53111 => prediction: 5  real class: 0
# Wrong Prediction 53112 => prediction: 8  real class: 6
# Wrong Prediction 53215 => prediction: 13  real class: 2
# Wrong Prediction 53252 => prediction: 8  real class: 9
# Wrong Prediction 53256 => prediction: 13  real class: 11
# Wrong Prediction 53279 => prediction: 11  real class: 2
# Wrong Prediction 53392 => prediction: 6  real class: 14
# Wrong Prediction 53475 => prediction: 14  real class: 3
# Wrong Prediction 53676 => prediction: 11  real class: 2
# Wrong Prediction 53761 => prediction: 4  real class: 15
# Wrong Prediction 53800 => prediction: 3  real class: 14
# Wrong Prediction 53914 => prediction: 13  real class: 3
# Wrong Prediction 54062 => prediction: 11  real class: 4
# Wrong Prediction 54134 => prediction: 1  real class: 14
# Wrong Prediction 54151 => prediction: 5  real class: 11
# Wrong Prediction 54240 => prediction: 14  real class: 7
# Wrong Prediction 54254 => prediction: 14  real class: 1
# Wrong Prediction 54268 => prediction: 14  real class: 7
# Wrong Prediction 54550 => prediction: 3  real class: 12
# Wrong Prediction 54605 => prediction: 4  real class: 2
# Wrong Prediction 54645 => prediction: 11  real class: 13
# Wrong Prediction 54743 => prediction: 8  real class: 1
# Wrong Prediction 54849 => prediction: 1  real class: 2
# Wrong Prediction 54986 => prediction: 13  real class: 3
# Wrong Prediction 55084 => prediction: 15  real class: 13
# Wrong Prediction 55399 => prediction: 7  real class: 6
# Wrong Prediction 55448 => prediction: 10  real class: 6
# Wrong Prediction 55489 => prediction: 7  real class: 1
# Wrong Prediction 55509 => prediction: 6  real class: 5
# Wrong Prediction 55512 => prediction: 10  real class: 11
# Wrong Prediction 55517 => prediction: 14  real class: 13
# Wrong Prediction 55535 => prediction: 4  real class: 14
# Wrong Prediction 55536 => prediction: 1  real class: 0
# Wrong Prediction 55586 => prediction: 12  real class: 6
# Wrong Prediction 55614 => prediction: 9  real class: 1
# Wrong Prediction 55720 => prediction: 9  real class: 7
# Wrong Prediction 55846 => prediction: 14  real class: 3
# Wrong Prediction 55847 => prediction: 13  real class: 1
# Wrong Prediction 55858 => prediction: 14  real class: 10
# Wrong Prediction 56045 => prediction: 1  real class: 8
# Wrong Prediction 56222 => prediction: 2  real class: 0
# Wrong Prediction 56349 => prediction: 13  real class: 11
# Wrong Prediction 56387 => prediction: 11  real class: 9
# Wrong Prediction 56410 => prediction: 3  real class: 13
# Wrong Prediction 56423 => prediction: 8  real class: 4
# Wrong Prediction 56566 => prediction: 9  real class: 2
# Wrong Prediction 56643 => prediction: 13  real class: 10
# Wrong Prediction 56801 => prediction: 11  real class: 7
# Wrong Prediction 56900 => prediction: 2  real class: 1
# Wrong Prediction 57007 => prediction: 3  real class: 1
# Wrong Prediction 57008 => prediction: 9  real class: 14
# Wrong Prediction 57267 => prediction: 12  real class: 10
# Wrong Prediction 57268 => prediction: 2  real class: 3
# Wrong Prediction 57286 => prediction: 13  real class: 12
# Wrong Prediction 57429 => prediction: 15  real class: 10
# Wrong Prediction 57481 => prediction: 7  real class: 9
# Wrong Prediction 57562 => prediction: 10  real class: 15
# Wrong Prediction 57649 => prediction: 13  real class: 9
# Wrong Prediction 57847 => prediction: 14  real class: 2
# Wrong Prediction 57902 => prediction: 15  real class: 1
# Wrong Prediction 58102 => prediction: 12  real class: 3
# Wrong Prediction 58157 => prediction: 5  real class: 7
# Wrong Prediction 58168 => prediction: 10  real class: 9
# Wrong Prediction 58393 => prediction: 1  real class: 15
# Wrong Prediction 58577 => prediction: 12  real class: 8
# Wrong Prediction 58587 => prediction: 1  real class: 9
# Wrong Prediction 58616 => prediction: 10  real class: 3
# Wrong Prediction 58652 => prediction: 11  real class: 4
# Wrong Prediction 58710 => prediction: 3  real class: 14
# Wrong Prediction 58804 => prediction: 15  real class: 0
# Wrong Prediction 58826 => prediction: 6  real class: 3
# Wrong Prediction 58891 => prediction: 6  real class: 11
# Wrong Prediction 58954 => prediction: 9  real class: 8
# Wrong Prediction 58998 => prediction: 6  real class: 7
# Wrong Prediction 59002 => prediction: 7  real class: 6
# Wrong Prediction 59388 => prediction: 7  real class: 10
# Wrong Prediction 59413 => prediction: 5  real class: 9
# Wrong Prediction 59542 => prediction: 15  real class: 7
# Wrong Prediction 59560 => prediction: 13  real class: 10
# Wrong Prediction 59756 => prediction: 15  real class: 5
# Wrong Prediction 59946 => prediction: 14  real class: 0
# For K =  9
# accuracy: 0.9890833333333333
# precision: 0.9890800036202679
# recall: 0.9890676535495522

# %%
# WITHOUT NORMALIZATION 
df_i_np = df_i.to_numpy()
df_d_np = df_d.to_numpy()

train_wn = df_i_np[:47999]  # Train_wn stands for "train without normalization".                       
test_wn = df_i_np[47999:]  # Test_wn stands for "test without normalization".

# %%
KNN(train_wn,test_wn,1,train_class,test_class)
# Out:
# Wrong Prediction 48076 => prediction: 13  real class: 14
# Wrong Prediction 48082 => prediction: 9  real class: 11
# Wrong Prediction 48189 => prediction: 1  real class: 13
# Wrong Prediction 48207 => prediction: 8  real class: 12
# Wrong Prediction 48332 => prediction: 6  real class: 15
# Wrong Prediction 48391 => prediction: 2  real class: 6
# Wrong Prediction 48413 => prediction: 13  real class: 7
# Wrong Prediction 48439 => prediction: 3  real class: 13
# Wrong Prediction 48538 => prediction: 1  real class: 13
# Wrong Prediction 48561 => prediction: 3  real class: 0
# Wrong Prediction 48588 => prediction: 5  real class: 8
# Wrong Prediction 48727 => prediction: 13  real class: 14
# Wrong Prediction 48741 => prediction: 15  real class: 13
# Wrong Prediction 48812 => prediction: 15  real class: 0
# Wrong Prediction 48905 => prediction: 2  real class: 6
# Wrong Prediction 48957 => prediction: 14  real class: 9
# Wrong Prediction 49007 => prediction: 6  real class: 12
# Wrong Prediction 49009 => prediction: 5  real class: 0
# Wrong Prediction 49036 => prediction: 14  real class: 7
# Wrong Prediction 49175 => prediction: 6  real class: 11
# Wrong Prediction 49233 => prediction: 13  real class: 14
# Wrong Prediction 49239 => prediction: 11  real class: 13
# Wrong Prediction 49244 => prediction: 14  real class: 9
# Wrong Prediction 49246 => prediction: 0  real class: 15
# Wrong Prediction 49366 => prediction: 3  real class: 11
# Wrong Prediction 49368 => prediction: 11  real class: 6
# Wrong Prediction 49416 => prediction: 7  real class: 3
# Wrong Prediction 49465 => prediction: 9  real class: 3
# Wrong Prediction 49486 => prediction: 2  real class: 7
# Wrong Prediction 49531 => prediction: 0  real class: 4
# Wrong Prediction 49581 => prediction: 15  real class: 6
# Wrong Prediction 49615 => prediction: 3  real class: 2
# Wrong Prediction 49690 => prediction: 3  real class: 15
# Wrong Prediction 49791 => prediction: 6  real class: 8
# Wrong Prediction 49806 => prediction: 7  real class: 15
# Wrong Prediction 49933 => prediction: 9  real class: 13
# Wrong Prediction 49960 => prediction: 4  real class: 15
# Wrong Prediction 49974 => prediction: 13  real class: 4
# Wrong Prediction 50016 => prediction: 3  real class: 1
# Wrong Prediction 50021 => prediction: 3  real class: 5
# Wrong Prediction 50114 => prediction: 15  real class: 13
# Wrong Prediction 50154 => prediction: 9  real class: 4
# Wrong Prediction 50170 => prediction: 5  real class: 14
# Wrong Prediction 50207 => prediction: 14  real class: 1
# Wrong Prediction 50303 => prediction: 8  real class: 5
# Wrong Prediction 50338 => prediction: 6  real class: 13
# Wrong Prediction 50409 => prediction: 2  real class: 5
# Wrong Prediction 50447 => prediction: 4  real class: 0
# Wrong Prediction 50458 => prediction: 13  real class: 14
# Wrong Prediction 50498 => prediction: 12  real class: 2
# Wrong Prediction 50513 => prediction: 1  real class: 15
# Wrong Prediction 50552 => prediction: 5  real class: 12
# Wrong Prediction 50593 => prediction: 15  real class: 10
# Wrong Prediction 50615 => prediction: 6  real class: 10
# Wrong Prediction 50632 => prediction: 13  real class: 3
# Wrong Prediction 50758 => prediction: 3  real class: 5
# Wrong Prediction 50765 => prediction: 14  real class: 4
# Wrong Prediction 50786 => prediction: 15  real class: 10
# Wrong Prediction 50795 => prediction: 14  real class: 4
# Wrong Prediction 50805 => prediction: 15  real class: 3
# Wrong Prediction 50881 => prediction: 1  real class: 10
# Wrong Prediction 50932 => prediction: 11  real class: 4
# Wrong Prediction 51031 => prediction: 14  real class: 6
# Wrong Prediction 51047 => prediction: 9  real class: 15
# Wrong Prediction 51123 => prediction: 6  real class: 2
# Wrong Prediction 51153 => prediction: 11  real class: 14
# Wrong Prediction 51155 => prediction: 10  real class: 4
# Wrong Prediction 51188 => prediction: 10  real class: 2
# Wrong Prediction 51207 => prediction: 1  real class: 14
# Wrong Prediction 51212 => prediction: 5  real class: 9
# Wrong Prediction 51234 => prediction: 9  real class: 2
# Wrong Prediction 51270 => prediction: 9  real class: 1
# Wrong Prediction 51277 => prediction: 4  real class: 1
# Wrong Prediction 51342 => prediction: 9  real class: 13
# Wrong Prediction 51364 => prediction: 1  real class: 8
# Wrong Prediction 51385 => prediction: 9  real class: 7
# Wrong Prediction 51484 => prediction: 6  real class: 15
# Wrong Prediction 51542 => prediction: 8  real class: 2
# Wrong Prediction 51543 => prediction: 12  real class: 8
# Wrong Prediction 51659 => prediction: 1  real class: 12
# Wrong Prediction 51692 => prediction: 14  real class: 2
# Wrong Prediction 51723 => prediction: 6  real class: 14
# Wrong Prediction 51759 => prediction: 11  real class: 0
# Wrong Prediction 51765 => prediction: 13  real class: 5
# Wrong Prediction 51833 => prediction: 8  real class: 5
# Wrong Prediction 51941 => prediction: 4  real class: 12
# Wrong Prediction 51962 => prediction: 14  real class: 7
# Wrong Prediction 52062 => prediction: 0  real class: 4
# Wrong Prediction 52160 => prediction: 6  real class: 5
# Wrong Prediction 52278 => prediction: 2  real class: 12
# Wrong Prediction 52296 => prediction: 8  real class: 2
# Wrong Prediction 52306 => prediction: 8  real class: 7
# Wrong Prediction 52541 => prediction: 14  real class: 4
# Wrong Prediction 52595 => prediction: 4  real class: 5
# Wrong Prediction 52623 => prediction: 9  real class: 11
# Wrong Prediction 52631 => prediction: 2  real class: 8
# Wrong Prediction 52652 => prediction: 14  real class: 5
# Wrong Prediction 52715 => prediction: 0  real class: 8
# Wrong Prediction 52764 => prediction: 14  real class: 2
# Wrong Prediction 52782 => prediction: 1  real class: 13
# Wrong Prediction 52784 => prediction: 5  real class: 9
# Wrong Prediction 52862 => prediction: 13  real class: 0
# Wrong Prediction 52925 => prediction: 11  real class: 7
# Wrong Prediction 52931 => prediction: 14  real class: 11
# Wrong Prediction 52989 => prediction: 1  real class: 4
# Wrong Prediction 53007 => prediction: 15  real class: 10
# Wrong Prediction 53076 => prediction: 2  real class: 0
# Wrong Prediction 53077 => prediction: 8  real class: 15
# Wrong Prediction 53101 => prediction: 7  real class: 1
# Wrong Prediction 53111 => prediction: 5  real class: 0
# Wrong Prediction 53112 => prediction: 8  real class: 6
# Wrong Prediction 53215 => prediction: 13  real class: 2
# Wrong Prediction 53256 => prediction: 13  real class: 11
# Wrong Prediction 53279 => prediction: 11  real class: 2
# Wrong Prediction 53389 => prediction: 5  real class: 8
# Wrong Prediction 53392 => prediction: 6  real class: 14
# Wrong Prediction 53475 => prediction: 14  real class: 3
# Wrong Prediction 53495 => prediction: 0  real class: 10
# Wrong Prediction 53568 => prediction: 1  real class: 3
# Wrong Prediction 53676 => prediction: 11  real class: 2
# Wrong Prediction 53761 => prediction: 4  real class: 15
# Wrong Prediction 53800 => prediction: 3  real class: 14
# Wrong Prediction 53896 => prediction: 13  real class: 7
# Wrong Prediction 53914 => prediction: 13  real class: 3
# Wrong Prediction 53942 => prediction: 13  real class: 12
# Wrong Prediction 53975 => prediction: 14  real class: 1
# Wrong Prediction 54043 => prediction: 11  real class: 6
# Wrong Prediction 54062 => prediction: 11  real class: 4
# Wrong Prediction 54095 => prediction: 6  real class: 12
# Wrong Prediction 54134 => prediction: 1  real class: 14
# Wrong Prediction 54151 => prediction: 5  real class: 11
# Wrong Prediction 54156 => prediction: 12  real class: 2
# Wrong Prediction 54171 => prediction: 6  real class: 5
# Wrong Prediction 54177 => prediction: 3  real class: 5
# Wrong Prediction 54217 => prediction: 12  real class: 6
# Wrong Prediction 54240 => prediction: 14  real class: 7
# Wrong Prediction 54254 => prediction: 14  real class: 1
# Wrong Prediction 54268 => prediction: 14  real class: 7
# Wrong Prediction 54320 => prediction: 3  real class: 14
# Wrong Prediction 54369 => prediction: 6  real class: 13
# Wrong Prediction 54428 => prediction: 3  real class: 10
# Wrong Prediction 54443 => prediction: 12  real class: 5
# Wrong Prediction 54452 => prediction: 10  real class: 4
# Wrong Prediction 54510 => prediction: 10  real class: 15
# Wrong Prediction 54550 => prediction: 3  real class: 12
# Wrong Prediction 54584 => prediction: 12  real class: 5
# Wrong Prediction 54605 => prediction: 14  real class: 2
# Wrong Prediction 54625 => prediction: 4  real class: 14
# Wrong Prediction 54645 => prediction: 11  real class: 13
# Wrong Prediction 54661 => prediction: 15  real class: 1
# Wrong Prediction 54743 => prediction: 8  real class: 1
# Wrong Prediction 54762 => prediction: 15  real class: 2
# Wrong Prediction 54849 => prediction: 1  real class: 2
# Wrong Prediction 54863 => prediction: 13  real class: 3
# Wrong Prediction 54986 => prediction: 13  real class: 3
# Wrong Prediction 55084 => prediction: 15  real class: 13
# Wrong Prediction 55272 => prediction: 4  real class: 15
# Wrong Prediction 55366 => prediction: 15  real class: 10
# Wrong Prediction 55390 => prediction: 14  real class: 5
# Wrong Prediction 55399 => prediction: 7  real class: 6
# Wrong Prediction 55403 => prediction: 11  real class: 15
# Wrong Prediction 55430 => prediction: 12  real class: 2
# Wrong Prediction 55448 => prediction: 10  real class: 6
# Wrong Prediction 55489 => prediction: 7  real class: 1
# Wrong Prediction 55509 => prediction: 6  real class: 5
# Wrong Prediction 55512 => prediction: 10  real class: 11
# Wrong Prediction 55517 => prediction: 14  real class: 13
# Wrong Prediction 55526 => prediction: 15  real class: 5
# Wrong Prediction 55535 => prediction: 4  real class: 14
# Wrong Prediction 55536 => prediction: 1  real class: 0
# Wrong Prediction 55586 => prediction: 12  real class: 6
# Wrong Prediction 55614 => prediction: 9  real class: 1
# Wrong Prediction 55638 => prediction: 1  real class: 9
# Wrong Prediction 55649 => prediction: 11  real class: 13
# Wrong Prediction 55720 => prediction: 9  real class: 7
# Wrong Prediction 55743 => prediction: 11  real class: 3
# Wrong Prediction 55799 => prediction: 6  real class: 8
# Wrong Prediction 55839 => prediction: 8  real class: 5
# Wrong Prediction 55846 => prediction: 14  real class: 3
# Wrong Prediction 55847 => prediction: 13  real class: 1
# Wrong Prediction 55858 => prediction: 14  real class: 10
# Wrong Prediction 56045 => prediction: 1  real class: 8
# Wrong Prediction 56048 => prediction: 1  real class: 13
# Wrong Prediction 56222 => prediction: 2  real class: 0
# Wrong Prediction 56244 => prediction: 6  real class: 10
# Wrong Prediction 56302 => prediction: 14  real class: 5
# Wrong Prediction 56349 => prediction: 13  real class: 11
# Wrong Prediction 56391 => prediction: 11  real class: 2
# Wrong Prediction 56410 => prediction: 3  real class: 13
# Wrong Prediction 56440 => prediction: 12  real class: 4
# Wrong Prediction 56566 => prediction: 9  real class: 2
# Wrong Prediction 56631 => prediction: 0  real class: 11
# Wrong Prediction 56635 => prediction: 8  real class: 9
# Wrong Prediction 56643 => prediction: 13  real class: 10
# Wrong Prediction 56714 => prediction: 5  real class: 6
# Wrong Prediction 56735 => prediction: 13  real class: 14
# Wrong Prediction 56801 => prediction: 11  real class: 7
# Wrong Prediction 56900 => prediction: 2  real class: 1
# Wrong Prediction 56906 => prediction: 14  real class: 4
# Wrong Prediction 56938 => prediction: 11  real class: 4
# Wrong Prediction 56965 => prediction: 1  real class: 7
# Wrong Prediction 56982 => prediction: 13  real class: 8
# Wrong Prediction 57007 => prediction: 3  real class: 1
# Wrong Prediction 57008 => prediction: 9  real class: 14
# Wrong Prediction 57074 => prediction: 11  real class: 14
# Wrong Prediction 57137 => prediction: 2  real class: 9
# Wrong Prediction 57267 => prediction: 12  real class: 10
# Wrong Prediction 57268 => prediction: 2  real class: 3
# Wrong Prediction 57286 => prediction: 13  real class: 12
# Wrong Prediction 57319 => prediction: 3  real class: 13
# Wrong Prediction 57393 => prediction: 5  real class: 10
# Wrong Prediction 57415 => prediction: 5  real class: 12
# Wrong Prediction 57429 => prediction: 15  real class: 10
# Wrong Prediction 57481 => prediction: 7  real class: 9
# Wrong Prediction 57561 => prediction: 4  real class: 15
# Wrong Prediction 57562 => prediction: 10  real class: 15
# Wrong Prediction 57649 => prediction: 13  real class: 9
# Wrong Prediction 57723 => prediction: 8  real class: 15
# Wrong Prediction 57843 => prediction: 15  real class: 13
# Wrong Prediction 57847 => prediction: 14  real class: 2
# Wrong Prediction 57885 => prediction: 4  real class: 6
# Wrong Prediction 57898 => prediction: 9  real class: 6
# Wrong Prediction 57902 => prediction: 15  real class: 1
# Wrong Prediction 57943 => prediction: 1  real class: 13
# Wrong Prediction 57989 => prediction: 5  real class: 2
# Wrong Prediction 58073 => prediction: 8  real class: 6
# Wrong Prediction 58102 => prediction: 12  real class: 3
# Wrong Prediction 58157 => prediction: 5  real class: 7
# Wrong Prediction 58162 => prediction: 2  real class: 6
# Wrong Prediction 58168 => prediction: 10  real class: 9
# Wrong Prediction 58205 => prediction: 4  real class: 15
# Wrong Prediction 58217 => prediction: 1  real class: 13
# Wrong Prediction 58393 => prediction: 1  real class: 15
# Wrong Prediction 58410 => prediction: 0  real class: 13
# Wrong Prediction 58421 => prediction: 9  real class: 13
# Wrong Prediction 58454 => prediction: 13  real class: 15
# Wrong Prediction 58458 => prediction: 0  real class: 10
# Wrong Prediction 58531 => prediction: 12  real class: 6
# Wrong Prediction 58577 => prediction: 12  real class: 8
# Wrong Prediction 58587 => prediction: 1  real class: 9
# Wrong Prediction 58604 => prediction: 6  real class: 15
# Wrong Prediction 58616 => prediction: 10  real class: 3
# Wrong Prediction 58652 => prediction: 11  real class: 4
# Wrong Prediction 58710 => prediction: 3  real class: 14
# Wrong Prediction 58804 => prediction: 15  real class: 0
# Wrong Prediction 58826 => prediction: 6  real class: 3
# Wrong Prediction 58891 => prediction: 6  real class: 11
# Wrong Prediction 58954 => prediction: 9  real class: 8
# Wrong Prediction 58998 => prediction: 6  real class: 7
# Wrong Prediction 59002 => prediction: 7  real class: 6
# Wrong Prediction 59012 => prediction: 6  real class: 15
# Wrong Prediction 59064 => prediction: 3  real class: 12
# Wrong Prediction 59086 => prediction: 2  real class: 6
# Wrong Prediction 59141 => prediction: 15  real class: 14
# Wrong Prediction 59235 => prediction: 11  real class: 3
# Wrong Prediction 59284 => prediction: 7  real class: 14
# Wrong Prediction 59311 => prediction: 15  real class: 1
# Wrong Prediction 59388 => prediction: 7  real class: 10
# Wrong Prediction 59413 => prediction: 5  real class: 9
# Wrong Prediction 59527 => prediction: 8  real class: 5
# Wrong Prediction 59542 => prediction: 15  real class: 7
# Wrong Prediction 59560 => prediction: 13  real class: 10
# Wrong Prediction 59591 => prediction: 14  real class: 8
# Wrong Prediction 59640 => prediction: 11  real class: 6
# Wrong Prediction 59756 => prediction: 15  real class: 5
# Wrong Prediction 59850 => prediction: 7  real class: 14
# Wrong Prediction 59946 => prediction: 14  real class: 0
# For K =  1
# accuracy: 0.97775
# precision: 0.977716560440014
# recall: 0.9776958364107582

# %%
KNN(train_wn,test_wn,3,train_class,test_class)
# Out:
# Wrong Prediction 48413 => prediction: 13  real class: 7
# Wrong Prediction 48561 => prediction: 3  real class: 0
# Wrong Prediction 48727 => prediction: 13  real class: 14
# Wrong Prediction 48741 => prediction: 15  real class: 13
# Wrong Prediction 48957 => prediction: 14  real class: 9
# Wrong Prediction 49036 => prediction: 14  real class: 7
# Wrong Prediction 49244 => prediction: 14  real class: 9
# Wrong Prediction 49366 => prediction: 3  real class: 11
# Wrong Prediction 49416 => prediction: 7  real class: 3
# Wrong Prediction 49465 => prediction: 9  real class: 3
# Wrong Prediction 49486 => prediction: 2  real class: 7
# Wrong Prediction 49581 => prediction: 15  real class: 6
# Wrong Prediction 49615 => prediction: 3  real class: 2
# Wrong Prediction 49690 => prediction: 3  real class: 15
# Wrong Prediction 49960 => prediction: 4  real class: 15
# Wrong Prediction 49974 => prediction: 13  real class: 4
# Wrong Prediction 50044 => prediction: 15  real class: 4
# Wrong Prediction 50045 => prediction: 0  real class: 5
# Wrong Prediction 50170 => prediction: 5  real class: 14
# Wrong Prediction 50409 => prediction: 2  real class: 5
# Wrong Prediction 50513 => prediction: 1  real class: 15
# Wrong Prediction 50632 => prediction: 13  real class: 3
# Wrong Prediction 50758 => prediction: 3  real class: 5
# Wrong Prediction 50805 => prediction: 15  real class: 3
# Wrong Prediction 50881 => prediction: 1  real class: 10
# Wrong Prediction 50932 => prediction: 11  real class: 4
# Wrong Prediction 51047 => prediction: 9  real class: 15
# Wrong Prediction 51123 => prediction: 6  real class: 2
# Wrong Prediction 51234 => prediction: 9  real class: 2
# Wrong Prediction 51270 => prediction: 9  real class: 1
# Wrong Prediction 51342 => prediction: 9  real class: 13
# Wrong Prediction 51364 => prediction: 1  real class: 8
# Wrong Prediction 51385 => prediction: 9  real class: 7
# Wrong Prediction 51659 => prediction: 1  real class: 12
# Wrong Prediction 51692 => prediction: 14  real class: 2
# Wrong Prediction 51759 => prediction: 11  real class: 0
# Wrong Prediction 51833 => prediction: 8  real class: 5
# Wrong Prediction 51962 => prediction: 14  real class: 7
# Wrong Prediction 52062 => prediction: 0  real class: 4
# Wrong Prediction 52160 => prediction: 6  real class: 5
# Wrong Prediction 52278 => prediction: 2  real class: 12
# Wrong Prediction 52296 => prediction: 8  real class: 2
# Wrong Prediction 52595 => prediction: 4  real class: 5
# Wrong Prediction 52652 => prediction: 14  real class: 5
# Wrong Prediction 52764 => prediction: 14  real class: 2
# Wrong Prediction 52780 => prediction: 14  real class: 7
# Wrong Prediction 52862 => prediction: 13  real class: 0
# Wrong Prediction 52989 => prediction: 1  real class: 4
# Wrong Prediction 53007 => prediction: 15  real class: 10
# Wrong Prediction 53056 => prediction: 11  real class: 14
# Wrong Prediction 53076 => prediction: 2  real class: 0
# Wrong Prediction 53077 => prediction: 8  real class: 15
# Wrong Prediction 53111 => prediction: 5  real class: 0
# Wrong Prediction 53112 => prediction: 8  real class: 6
# Wrong Prediction 53215 => prediction: 13  real class: 2
# Wrong Prediction 53256 => prediction: 13  real class: 11
# Wrong Prediction 53279 => prediction: 11  real class: 2
# Wrong Prediction 53392 => prediction: 6  real class: 14
# Wrong Prediction 53475 => prediction: 14  real class: 3
# Wrong Prediction 53676 => prediction: 11  real class: 2
# Wrong Prediction 53761 => prediction: 4  real class: 15
# Wrong Prediction 53800 => prediction: 3  real class: 14
# Wrong Prediction 53896 => prediction: 4  real class: 7
# Wrong Prediction 53914 => prediction: 13  real class: 3
# Wrong Prediction 54062 => prediction: 11  real class: 4
# Wrong Prediction 54134 => prediction: 1  real class: 14
# Wrong Prediction 54151 => prediction: 5  real class: 11
# Wrong Prediction 54171 => prediction: 12  real class: 5
# Wrong Prediction 54240 => prediction: 14  real class: 7
# Wrong Prediction 54254 => prediction: 14  real class: 1
# Wrong Prediction 54268 => prediction: 14  real class: 7
# Wrong Prediction 54320 => prediction: 2  real class: 14
# Wrong Prediction 54550 => prediction: 3  real class: 12
# Wrong Prediction 54605 => prediction: 4  real class: 2
# Wrong Prediction 54645 => prediction: 11  real class: 13
# Wrong Prediction 54743 => prediction: 8  real class: 1
# Wrong Prediction 54849 => prediction: 1  real class: 2
# Wrong Prediction 54863 => prediction: 5  real class: 3
# Wrong Prediction 54986 => prediction: 13  real class: 3
# Wrong Prediction 55084 => prediction: 15  real class: 13
# Wrong Prediction 55399 => prediction: 7  real class: 6
# Wrong Prediction 55448 => prediction: 10  real class: 6
# Wrong Prediction 55489 => prediction: 7  real class: 1
# Wrong Prediction 55509 => prediction: 6  real class: 5
# Wrong Prediction 55512 => prediction: 10  real class: 11
# Wrong Prediction 55517 => prediction: 14  real class: 13
# Wrong Prediction 55526 => prediction: 3  real class: 5
# Wrong Prediction 55535 => prediction: 4  real class: 14
# Wrong Prediction 55536 => prediction: 1  real class: 0
# Wrong Prediction 55586 => prediction: 12  real class: 6
# Wrong Prediction 55614 => prediction: 9  real class: 1
# Wrong Prediction 55720 => prediction: 9  real class: 7
# Wrong Prediction 55846 => prediction: 14  real class: 3
# Wrong Prediction 55847 => prediction: 13  real class: 1
# Wrong Prediction 55858 => prediction: 14  real class: 10
# Wrong Prediction 56045 => prediction: 1  real class: 8
# Wrong Prediction 56222 => prediction: 2  real class: 0
# Wrong Prediction 56349 => prediction: 13  real class: 11
# Wrong Prediction 56410 => prediction: 3  real class: 13
# Wrong Prediction 56566 => prediction: 9  real class: 2
# Wrong Prediction 56643 => prediction: 13  real class: 10
# Wrong Prediction 56735 => prediction: 2  real class: 14
# Wrong Prediction 56801 => prediction: 11  real class: 7
# Wrong Prediction 56900 => prediction: 2  real class: 1
# Wrong Prediction 57007 => prediction: 3  real class: 1
# Wrong Prediction 57008 => prediction: 9  real class: 14
# Wrong Prediction 57137 => prediction: 2  real class: 9
# Wrong Prediction 57267 => prediction: 12  real class: 10
# Wrong Prediction 57268 => prediction: 2  real class: 3
# Wrong Prediction 57286 => prediction: 13  real class: 12
# Wrong Prediction 57429 => prediction: 15  real class: 10
# Wrong Prediction 57481 => prediction: 7  real class: 9
# Wrong Prediction 57562 => prediction: 10  real class: 15
# Wrong Prediction 57649 => prediction: 13  real class: 9
# Wrong Prediction 57843 => prediction: 15  real class: 13
# Wrong Prediction 57847 => prediction: 14  real class: 2
# Wrong Prediction 57902 => prediction: 15  real class: 1
# Wrong Prediction 57943 => prediction: 1  real class: 13
# Wrong Prediction 57989 => prediction: 10  real class: 2
# Wrong Prediction 58102 => prediction: 12  real class: 3
# Wrong Prediction 58157 => prediction: 5  real class: 7
# Wrong Prediction 58168 => prediction: 10  real class: 9
# Wrong Prediction 58393 => prediction: 1  real class: 15
# Wrong Prediction 58577 => prediction: 12  real class: 8
# Wrong Prediction 58587 => prediction: 1  real class: 9
# Wrong Prediction 58616 => prediction: 10  real class: 3
# Wrong Prediction 58652 => prediction: 11  real class: 4
# Wrong Prediction 58710 => prediction: 3  real class: 14
# Wrong Prediction 58804 => prediction: 15  real class: 0
# Wrong Prediction 58826 => prediction: 6  real class: 3
# Wrong Prediction 58891 => prediction: 6  real class: 11
# Wrong Prediction 58954 => prediction: 9  real class: 8
# Wrong Prediction 58998 => prediction: 6  real class: 7
# Wrong Prediction 59002 => prediction: 7  real class: 6
# Wrong Prediction 59086 => prediction: 2  real class: 6
# Wrong Prediction 59388 => prediction: 7  real class: 10
# Wrong Prediction 59413 => prediction: 5  real class: 9
# Wrong Prediction 59542 => prediction: 15  real class: 7
# Wrong Prediction 59560 => prediction: 13  real class: 10
# Wrong Prediction 59756 => prediction: 15  real class: 5
# Wrong Prediction 59946 => prediction: 14  real class: 0
# For K =  3
# accuracy: 0.98825
# precision: 0.9882404225423297
# recall: 0.988217225253303

# %%
KNN(train_wn,test_wn,5,train_class,test_class)
# Out:
# Wrong Prediction 48561 => prediction: 3  real class: 0
# Wrong Prediction 48727 => prediction: 13  real class: 14
# Wrong Prediction 48741 => prediction: 15  real class: 13
# Wrong Prediction 48957 => prediction: 14  real class: 9
# Wrong Prediction 49036 => prediction: 14  real class: 7
# Wrong Prediction 49244 => prediction: 14  real class: 9
# Wrong Prediction 49366 => prediction: 3  real class: 11
# Wrong Prediction 49416 => prediction: 7  real class: 3
# Wrong Prediction 49465 => prediction: 9  real class: 3
# Wrong Prediction 49486 => prediction: 2  real class: 7
# Wrong Prediction 49581 => prediction: 15  real class: 6
# Wrong Prediction 49615 => prediction: 3  real class: 2
# Wrong Prediction 49690 => prediction: 3  real class: 15
# Wrong Prediction 49960 => prediction: 4  real class: 15
# Wrong Prediction 49974 => prediction: 13  real class: 4
# Wrong Prediction 50044 => prediction: 15  real class: 4
# Wrong Prediction 50045 => prediction: 0  real class: 5
# Wrong Prediction 50170 => prediction: 5  real class: 14
# Wrong Prediction 50409 => prediction: 2  real class: 5
# Wrong Prediction 50513 => prediction: 1  real class: 15
# Wrong Prediction 50632 => prediction: 13  real class: 3
# Wrong Prediction 50758 => prediction: 3  real class: 5
# Wrong Prediction 50805 => prediction: 15  real class: 3
# Wrong Prediction 50881 => prediction: 1  real class: 10
# Wrong Prediction 50932 => prediction: 11  real class: 4
# Wrong Prediction 51047 => prediction: 9  real class: 15
# Wrong Prediction 51123 => prediction: 6  real class: 2
# Wrong Prediction 51234 => prediction: 9  real class: 2
# Wrong Prediction 51270 => prediction: 9  real class: 1
# Wrong Prediction 51342 => prediction: 9  real class: 13
# Wrong Prediction 51364 => prediction: 1  real class: 8
# Wrong Prediction 51385 => prediction: 9  real class: 7
# Wrong Prediction 51659 => prediction: 1  real class: 12
# Wrong Prediction 51692 => prediction: 14  real class: 2
# Wrong Prediction 51759 => prediction: 11  real class: 0
# Wrong Prediction 51833 => prediction: 8  real class: 5
# Wrong Prediction 51962 => prediction: 14  real class: 7
# Wrong Prediction 52062 => prediction: 0  real class: 4
# Wrong Prediction 52160 => prediction: 6  real class: 5
# Wrong Prediction 52278 => prediction: 2  real class: 12
# Wrong Prediction 52296 => prediction: 8  real class: 2
# Wrong Prediction 52595 => prediction: 4  real class: 5
# Wrong Prediction 52652 => prediction: 14  real class: 5
# Wrong Prediction 52764 => prediction: 14  real class: 2
# Wrong Prediction 52780 => prediction: 14  real class: 7
# Wrong Prediction 52784 => prediction: 5  real class: 9
# Wrong Prediction 52862 => prediction: 13  real class: 0
# Wrong Prediction 52934 => prediction: 6  real class: 8
# Wrong Prediction 52989 => prediction: 1  real class: 4
# Wrong Prediction 53007 => prediction: 15  real class: 10
# Wrong Prediction 53076 => prediction: 2  real class: 0
# Wrong Prediction 53077 => prediction: 8  real class: 15
# Wrong Prediction 53111 => prediction: 5  real class: 0
# Wrong Prediction 53112 => prediction: 8  real class: 6
# Wrong Prediction 53215 => prediction: 13  real class: 2
# Wrong Prediction 53252 => prediction: 8  real class: 9
# Wrong Prediction 53256 => prediction: 13  real class: 11
# Wrong Prediction 53279 => prediction: 11  real class: 2
# Wrong Prediction 53392 => prediction: 6  real class: 14
# Wrong Prediction 53475 => prediction: 14  real class: 3
# Wrong Prediction 53676 => prediction: 11  real class: 2
# Wrong Prediction 53761 => prediction: 4  real class: 15
# Wrong Prediction 53800 => prediction: 3  real class: 14
# Wrong Prediction 53896 => prediction: 13  real class: 7
# Wrong Prediction 53914 => prediction: 13  real class: 3
# Wrong Prediction 54062 => prediction: 11  real class: 4
# Wrong Prediction 54134 => prediction: 1  real class: 14
# Wrong Prediction 54151 => prediction: 5  real class: 11
# Wrong Prediction 54240 => prediction: 14  real class: 7
# Wrong Prediction 54254 => prediction: 14  real class: 1
# Wrong Prediction 54268 => prediction: 14  real class: 7
# Wrong Prediction 54550 => prediction: 3  real class: 12
# Wrong Prediction 54605 => prediction: 4  real class: 2
# Wrong Prediction 54645 => prediction: 11  real class: 13
# Wrong Prediction 54743 => prediction: 8  real class: 1
# Wrong Prediction 54849 => prediction: 1  real class: 2
# Wrong Prediction 54986 => prediction: 13  real class: 3
# Wrong Prediction 55084 => prediction: 15  real class: 13
# Wrong Prediction 55334 => prediction: 15  real class: 8
# Wrong Prediction 55399 => prediction: 7  real class: 6
# Wrong Prediction 55448 => prediction: 10  real class: 6
# Wrong Prediction 55489 => prediction: 7  real class: 1
# Wrong Prediction 55509 => prediction: 6  real class: 5
# Wrong Prediction 55512 => prediction: 10  real class: 11
# Wrong Prediction 55517 => prediction: 14  real class: 13
# Wrong Prediction 55526 => prediction: 3  real class: 5
# Wrong Prediction 55535 => prediction: 4  real class: 14
# Wrong Prediction 55536 => prediction: 1  real class: 0
# Wrong Prediction 55586 => prediction: 12  real class: 6
# Wrong Prediction 55614 => prediction: 9  real class: 1
# Wrong Prediction 55720 => prediction: 9  real class: 7
# Wrong Prediction 55846 => prediction: 14  real class: 3
# Wrong Prediction 55847 => prediction: 13  real class: 1
# Wrong Prediction 55858 => prediction: 14  real class: 10
# Wrong Prediction 56045 => prediction: 1  real class: 8
# Wrong Prediction 56222 => prediction: 2  real class: 0
# Wrong Prediction 56349 => prediction: 13  real class: 11
# Wrong Prediction 56410 => prediction: 3  real class: 13
# Wrong Prediction 56566 => prediction: 9  real class: 2
# Wrong Prediction 56643 => prediction: 13  real class: 10
# Wrong Prediction 56801 => prediction: 11  real class: 7
# Wrong Prediction 56900 => prediction: 2  real class: 1
# Wrong Prediction 57007 => prediction: 3  real class: 1
# Wrong Prediction 57008 => prediction: 9  real class: 14
# Wrong Prediction 57267 => prediction: 12  real class: 10
# Wrong Prediction 57268 => prediction: 2  real class: 3
# Wrong Prediction 57286 => prediction: 13  real class: 12
# Wrong Prediction 57429 => prediction: 15  real class: 10
# Wrong Prediction 57481 => prediction: 7  real class: 9
# Wrong Prediction 57562 => prediction: 10  real class: 15
# Wrong Prediction 57649 => prediction: 13  real class: 9
# Wrong Prediction 57847 => prediction: 14  real class: 2
# Wrong Prediction 57902 => prediction: 15  real class: 1
# Wrong Prediction 58102 => prediction: 12  real class: 3
# Wrong Prediction 58157 => prediction: 5  real class: 7
# Wrong Prediction 58168 => prediction: 10  real class: 9
# Wrong Prediction 58393 => prediction: 1  real class: 15
# Wrong Prediction 58577 => prediction: 12  real class: 8
# Wrong Prediction 58587 => prediction: 1  real class: 9
# Wrong Prediction 58616 => prediction: 10  real class: 3
# Wrong Prediction 58652 => prediction: 11  real class: 4
# Wrong Prediction 58710 => prediction: 3  real class: 14
# Wrong Prediction 58804 => prediction: 15  real class: 0
# Wrong Prediction 58826 => prediction: 6  real class: 3
# Wrong Prediction 58891 => prediction: 6  real class: 11
# Wrong Prediction 58954 => prediction: 9  real class: 8
# Wrong Prediction 58998 => prediction: 6  real class: 7
# Wrong Prediction 59002 => prediction: 7  real class: 6
# Wrong Prediction 59086 => prediction: 2  real class: 6
# Wrong Prediction 59388 => prediction: 7  real class: 10
# Wrong Prediction 59413 => prediction: 5  real class: 9
# Wrong Prediction 59542 => prediction: 15  real class: 7
# Wrong Prediction 59560 => prediction: 13  real class: 10
# Wrong Prediction 59756 => prediction: 15  real class: 5
# Wrong Prediction 59946 => prediction: 14  real class: 0
# For K =  5
# accuracy: 0.98875
# precision: 0.9887398079282843
# recall: 0.9887313457560725

# %%
KNN(train_wn,test_wn,7,train_class,test_class)
# Out:
# Wrong Prediction 48561 => prediction: 3  real class: 0
# Wrong Prediction 48727 => prediction: 13  real class: 14
# Wrong Prediction 48741 => prediction: 15  real class: 13
# Wrong Prediction 48957 => prediction: 14  real class: 9
# Wrong Prediction 49036 => prediction: 14  real class: 7
# Wrong Prediction 49244 => prediction: 14  real class: 9
# Wrong Prediction 49366 => prediction: 3  real class: 11
# Wrong Prediction 49416 => prediction: 7  real class: 3
# Wrong Prediction 49465 => prediction: 9  real class: 3
# Wrong Prediction 49486 => prediction: 2  real class: 7
# Wrong Prediction 49581 => prediction: 15  real class: 6
# Wrong Prediction 49615 => prediction: 3  real class: 2
# Wrong Prediction 49690 => prediction: 3  real class: 15
# Wrong Prediction 49960 => prediction: 4  real class: 15
# Wrong Prediction 49974 => prediction: 13  real class: 4
# Wrong Prediction 50044 => prediction: 15  real class: 4
# Wrong Prediction 50045 => prediction: 0  real class: 5
# Wrong Prediction 50170 => prediction: 5  real class: 14
# Wrong Prediction 50409 => prediction: 2  real class: 5
# Wrong Prediction 50513 => prediction: 1  real class: 15
# Wrong Prediction 50600 => prediction: 11  real class: 12
# Wrong Prediction 50632 => prediction: 13  real class: 3
# Wrong Prediction 50758 => prediction: 3  real class: 5
# Wrong Prediction 50805 => prediction: 15  real class: 3
# Wrong Prediction 50881 => prediction: 1  real class: 10
# Wrong Prediction 50932 => prediction: 11  real class: 4
# Wrong Prediction 51047 => prediction: 9  real class: 15
# Wrong Prediction 51123 => prediction: 6  real class: 2
# Wrong Prediction 51234 => prediction: 9  real class: 2
# Wrong Prediction 51270 => prediction: 9  real class: 1
# Wrong Prediction 51342 => prediction: 9  real class: 13
# Wrong Prediction 51364 => prediction: 1  real class: 8
# Wrong Prediction 51385 => prediction: 9  real class: 7
# Wrong Prediction 51659 => prediction: 1  real class: 12
# Wrong Prediction 51692 => prediction: 14  real class: 2
# Wrong Prediction 51759 => prediction: 11  real class: 0
# Wrong Prediction 51833 => prediction: 8  real class: 5
# Wrong Prediction 51962 => prediction: 14  real class: 7
# Wrong Prediction 52062 => prediction: 0  real class: 4
# Wrong Prediction 52160 => prediction: 6  real class: 5
# Wrong Prediction 52278 => prediction: 2  real class: 12
# Wrong Prediction 52296 => prediction: 8  real class: 2
# Wrong Prediction 52595 => prediction: 4  real class: 5
# Wrong Prediction 52652 => prediction: 14  real class: 5
# Wrong Prediction 52764 => prediction: 14  real class: 2
# Wrong Prediction 52780 => prediction: 14  real class: 7
# Wrong Prediction 52784 => prediction: 5  real class: 9
# Wrong Prediction 52862 => prediction: 13  real class: 0
# Wrong Prediction 52989 => prediction: 1  real class: 4
# Wrong Prediction 53007 => prediction: 15  real class: 10
# Wrong Prediction 53076 => prediction: 2  real class: 0
# Wrong Prediction 53077 => prediction: 8  real class: 15
# Wrong Prediction 53111 => prediction: 5  real class: 0
# Wrong Prediction 53112 => prediction: 8  real class: 6
# Wrong Prediction 53215 => prediction: 13  real class: 2
# Wrong Prediction 53252 => prediction: 7  real class: 9
# Wrong Prediction 53256 => prediction: 13  real class: 11
# Wrong Prediction 53279 => prediction: 11  real class: 2
# Wrong Prediction 53392 => prediction: 6  real class: 14
# Wrong Prediction 53475 => prediction: 14  real class: 3
# Wrong Prediction 53676 => prediction: 11  real class: 2
# Wrong Prediction 53761 => prediction: 4  real class: 15
# Wrong Prediction 53800 => prediction: 3  real class: 14
# Wrong Prediction 53914 => prediction: 13  real class: 3
# Wrong Prediction 54062 => prediction: 11  real class: 4
# Wrong Prediction 54134 => prediction: 1  real class: 14
# Wrong Prediction 54151 => prediction: 5  real class: 11
# Wrong Prediction 54240 => prediction: 14  real class: 7
# Wrong Prediction 54254 => prediction: 14  real class: 1
# Wrong Prediction 54268 => prediction: 14  real class: 7
# Wrong Prediction 54550 => prediction: 3  real class: 12
# Wrong Prediction 54605 => prediction: 4  real class: 2
# Wrong Prediction 54645 => prediction: 11  real class: 13
# Wrong Prediction 54743 => prediction: 8  real class: 1
# Wrong Prediction 54849 => prediction: 1  real class: 2
# Wrong Prediction 54986 => prediction: 13  real class: 3
# Wrong Prediction 55084 => prediction: 15  real class: 13
# Wrong Prediction 55399 => prediction: 7  real class: 6
# Wrong Prediction 55448 => prediction: 10  real class: 6
# Wrong Prediction 55489 => prediction: 7  real class: 1
# Wrong Prediction 55509 => prediction: 6  real class: 5
# Wrong Prediction 55512 => prediction: 10  real class: 11
# Wrong Prediction 55517 => prediction: 14  real class: 13
# Wrong Prediction 55526 => prediction: 15  real class: 5
# Wrong Prediction 55535 => prediction: 4  real class: 14
# Wrong Prediction 55536 => prediction: 1  real class: 0
# Wrong Prediction 55586 => prediction: 12  real class: 6
# Wrong Prediction 55614 => prediction: 9  real class: 1
# Wrong Prediction 55720 => prediction: 9  real class: 7
# Wrong Prediction 55846 => prediction: 14  real class: 3
# Wrong Prediction 55847 => prediction: 13  real class: 1
# Wrong Prediction 55858 => prediction: 14  real class: 10
# Wrong Prediction 56045 => prediction: 1  real class: 8
# Wrong Prediction 56222 => prediction: 2  real class: 0
# Wrong Prediction 56349 => prediction: 13  real class: 11
# Wrong Prediction 56410 => prediction: 3  real class: 13
# Wrong Prediction 56423 => prediction: 8  real class: 4
# Wrong Prediction 56566 => prediction: 9  real class: 2
# Wrong Prediction 56643 => prediction: 13  real class: 10
# Wrong Prediction 56801 => prediction: 11  real class: 7
# Wrong Prediction 56900 => prediction: 2  real class: 1
# Wrong Prediction 57007 => prediction: 3  real class: 1
# Wrong Prediction 57008 => prediction: 9  real class: 14
# Wrong Prediction 57267 => prediction: 12  real class: 10
# Wrong Prediction 57268 => prediction: 2  real class: 3
# Wrong Prediction 57286 => prediction: 13  real class: 12
# Wrong Prediction 57429 => prediction: 15  real class: 10
# Wrong Prediction 57481 => prediction: 7  real class: 9
# Wrong Prediction 57562 => prediction: 10  real class: 15
# Wrong Prediction 57649 => prediction: 13  real class: 9
# Wrong Prediction 57847 => prediction: 14  real class: 2
# Wrong Prediction 57902 => prediction: 15  real class: 1
# Wrong Prediction 58102 => prediction: 12  real class: 3
# Wrong Prediction 58157 => prediction: 5  real class: 7
# Wrong Prediction 58168 => prediction: 10  real class: 9
# Wrong Prediction 58393 => prediction: 1  real class: 15
# Wrong Prediction 58577 => prediction: 12  real class: 8
# Wrong Prediction 58587 => prediction: 1  real class: 9
# Wrong Prediction 58616 => prediction: 10  real class: 3
# Wrong Prediction 58652 => prediction: 11  real class: 4
# Wrong Prediction 58710 => prediction: 3  real class: 14
# Wrong Prediction 58804 => prediction: 15  real class: 0
# Wrong Prediction 58826 => prediction: 6  real class: 3
# Wrong Prediction 58891 => prediction: 6  real class: 11
# Wrong Prediction 58954 => prediction: 9  real class: 8
# Wrong Prediction 58998 => prediction: 6  real class: 7
# Wrong Prediction 59002 => prediction: 7  real class: 6
# Wrong Prediction 59086 => prediction: 2  real class: 6
# Wrong Prediction 59388 => prediction: 7  real class: 10
# Wrong Prediction 59413 => prediction: 5  real class: 9
# Wrong Prediction 59542 => prediction: 15  real class: 7
# Wrong Prediction 59560 => prediction: 13  real class: 10
# Wrong Prediction 59756 => prediction: 15  real class: 5
# Wrong Prediction 59946 => prediction: 14  real class: 0
# For K =  7
# accuracy: 0.9888333333333333
# precision: 0.9888283142603189
# recall: 0.9888124583311716

# %%
KNN(train_wn,test_wn,9,train_class,test_class)
# Out:
# Wrong Prediction 48561 => prediction: 3  real class: 0
# Wrong Prediction 48727 => prediction: 13  real class: 14
# Wrong Prediction 48741 => prediction: 15  real class: 13
# Wrong Prediction 48957 => prediction: 14  real class: 9
# Wrong Prediction 49036 => prediction: 14  real class: 7
# Wrong Prediction 49244 => prediction: 14  real class: 9
# Wrong Prediction 49366 => prediction: 3  real class: 11
# Wrong Prediction 49416 => prediction: 7  real class: 3
# Wrong Prediction 49465 => prediction: 9  real class: 3
# Wrong Prediction 49486 => prediction: 2  real class: 7
# Wrong Prediction 49581 => prediction: 15  real class: 6
# Wrong Prediction 49615 => prediction: 3  real class: 2
# Wrong Prediction 49690 => prediction: 3  real class: 15
# Wrong Prediction 49960 => prediction: 4  real class: 15
# Wrong Prediction 49974 => prediction: 13  real class: 4
# Wrong Prediction 50044 => prediction: 15  real class: 4
# Wrong Prediction 50045 => prediction: 0  real class: 5
# Wrong Prediction 50170 => prediction: 5  real class: 14
# Wrong Prediction 50409 => prediction: 2  real class: 5
# Wrong Prediction 50513 => prediction: 1  real class: 15
# Wrong Prediction 50632 => prediction: 13  real class: 3
# Wrong Prediction 50758 => prediction: 3  real class: 5
# Wrong Prediction 50805 => prediction: 15  real class: 3
# Wrong Prediction 50881 => prediction: 1  real class: 10
# Wrong Prediction 50932 => prediction: 11  real class: 4
# Wrong Prediction 51047 => prediction: 9  real class: 15
# Wrong Prediction 51123 => prediction: 6  real class: 2
# Wrong Prediction 51234 => prediction: 9  real class: 2
# Wrong Prediction 51270 => prediction: 9  real class: 1
# Wrong Prediction 51342 => prediction: 9  real class: 13
# Wrong Prediction 51364 => prediction: 1  real class: 8
# Wrong Prediction 51385 => prediction: 9  real class: 7
# Wrong Prediction 51659 => prediction: 1  real class: 12
# Wrong Prediction 51692 => prediction: 14  real class: 2
# Wrong Prediction 51759 => prediction: 11  real class: 0
# Wrong Prediction 51833 => prediction: 8  real class: 5
# Wrong Prediction 51962 => prediction: 14  real class: 7
# Wrong Prediction 52062 => prediction: 0  real class: 4
# Wrong Prediction 52160 => prediction: 6  real class: 5
# Wrong Prediction 52278 => prediction: 2  real class: 12
# Wrong Prediction 52296 => prediction: 8  real class: 2
# Wrong Prediction 52595 => prediction: 4  real class: 5
# Wrong Prediction 52652 => prediction: 14  real class: 5
# Wrong Prediction 52764 => prediction: 14  real class: 2
# Wrong Prediction 52780 => prediction: 14  real class: 7
# Wrong Prediction 52784 => prediction: 5  real class: 9
# Wrong Prediction 52862 => prediction: 13  real class: 0
# Wrong Prediction 52989 => prediction: 1  real class: 4
# Wrong Prediction 53007 => prediction: 15  real class: 10
# Wrong Prediction 53076 => prediction: 2  real class: 0
# Wrong Prediction 53077 => prediction: 8  real class: 15
# Wrong Prediction 53111 => prediction: 5  real class: 0
# Wrong Prediction 53112 => prediction: 8  real class: 6
# Wrong Prediction 53215 => prediction: 13  real class: 2
# Wrong Prediction 53252 => prediction: 8  real class: 9
# Wrong Prediction 53256 => prediction: 13  real class: 11
# Wrong Prediction 53279 => prediction: 11  real class: 2
# Wrong Prediction 53392 => prediction: 6  real class: 14
# Wrong Prediction 53475 => prediction: 14  real class: 3
# Wrong Prediction 53676 => prediction: 11  real class: 2
# Wrong Prediction 53761 => prediction: 4  real class: 15
# Wrong Prediction 53800 => prediction: 3  real class: 14
# Wrong Prediction 53914 => prediction: 13  real class: 3
# Wrong Prediction 54062 => prediction: 11  real class: 4
# Wrong Prediction 54134 => prediction: 1  real class: 14
# Wrong Prediction 54151 => prediction: 5  real class: 11
# Wrong Prediction 54240 => prediction: 14  real class: 7
# Wrong Prediction 54254 => prediction: 14  real class: 1
# Wrong Prediction 54268 => prediction: 14  real class: 7
# Wrong Prediction 54550 => prediction: 3  real class: 12
# Wrong Prediction 54605 => prediction: 4  real class: 2
# Wrong Prediction 54645 => prediction: 11  real class: 13
# Wrong Prediction 54743 => prediction: 8  real class: 1
# Wrong Prediction 54849 => prediction: 1  real class: 2
# Wrong Prediction 54986 => prediction: 13  real class: 3
# Wrong Prediction 55084 => prediction: 15  real class: 13
# Wrong Prediction 55399 => prediction: 7  real class: 6
# Wrong Prediction 55448 => prediction: 10  real class: 6
# Wrong Prediction 55489 => prediction: 7  real class: 1
# Wrong Prediction 55509 => prediction: 6  real class: 5
# Wrong Prediction 55512 => prediction: 10  real class: 11
# Wrong Prediction 55517 => prediction: 14  real class: 13
# Wrong Prediction 55535 => prediction: 4  real class: 14
# Wrong Prediction 55536 => prediction: 1  real class: 0
# Wrong Prediction 55586 => prediction: 12  real class: 6
# Wrong Prediction 55614 => prediction: 9  real class: 1
# Wrong Prediction 55720 => prediction: 9  real class: 7
# Wrong Prediction 55846 => prediction: 14  real class: 3
# Wrong Prediction 55847 => prediction: 13  real class: 1
# Wrong Prediction 55858 => prediction: 14  real class: 10
# Wrong Prediction 56045 => prediction: 1  real class: 8
# Wrong Prediction 56222 => prediction: 2  real class: 0
# Wrong Prediction 56349 => prediction: 13  real class: 11
# Wrong Prediction 56387 => prediction: 11  real class: 9
# Wrong Prediction 56410 => prediction: 3  real class: 13
# Wrong Prediction 56423 => prediction: 8  real class: 4
# Wrong Prediction 56566 => prediction: 9  real class: 2
# Wrong Prediction 56643 => prediction: 13  real class: 10
# Wrong Prediction 56801 => prediction: 11  real class: 7
# Wrong Prediction 56900 => prediction: 2  real class: 1
# Wrong Prediction 57007 => prediction: 3  real class: 1
# Wrong Prediction 57008 => prediction: 9  real class: 14
# Wrong Prediction 57267 => prediction: 12  real class: 10
# Wrong Prediction 57268 => prediction: 2  real class: 3
# Wrong Prediction 57286 => prediction: 13  real class: 12
# Wrong Prediction 57429 => prediction: 15  real class: 10
# Wrong Prediction 57481 => prediction: 7  real class: 9
# Wrong Prediction 57562 => prediction: 10  real class: 15
# Wrong Prediction 57649 => prediction: 13  real class: 9
# Wrong Prediction 57847 => prediction: 14  real class: 2
# Wrong Prediction 57902 => prediction: 15  real class: 1
# Wrong Prediction 58102 => prediction: 12  real class: 3
# Wrong Prediction 58157 => prediction: 5  real class: 7
# Wrong Prediction 58168 => prediction: 10  real class: 9
# Wrong Prediction 58393 => prediction: 1  real class: 15
# Wrong Prediction 58577 => prediction: 12  real class: 8
# Wrong Prediction 58587 => prediction: 1  real class: 9
# Wrong Prediction 58616 => prediction: 10  real class: 3
# Wrong Prediction 58652 => prediction: 11  real class: 4
# Wrong Prediction 58710 => prediction: 3  real class: 14
# Wrong Prediction 58804 => prediction: 15  real class: 0
# Wrong Prediction 58826 => prediction: 6  real class: 3
# Wrong Prediction 58891 => prediction: 6  real class: 11
# Wrong Prediction 58954 => prediction: 9  real class: 8
# Wrong Prediction 58998 => prediction: 6  real class: 7
# Wrong Prediction 59002 => prediction: 7  real class: 6
# Wrong Prediction 59388 => prediction: 7  real class: 10
# Wrong Prediction 59413 => prediction: 5  real class: 9
# Wrong Prediction 59542 => prediction: 15  real class: 7
# Wrong Prediction 59560 => prediction: 13  real class: 10
# Wrong Prediction 59756 => prediction: 15  real class: 5
# Wrong Prediction 59946 => prediction: 14  real class: 0
# For K =  9
# accuracy: 0.989
# precision: 0.9889955472083461
# recall: 0.9889839855441974

# %% [markdown]
# Gülvera Yazılıtaş b2210356111
#
#                                                  REPORT
#  Analyses
#
#  1-) When I normalized Data I get these results;
#
#  K = 1
# accuracy: 0.9783333333333334
# precision: 0.9783042430177052
# recall: 0.9782880233852064
#
#  K = 3
# accuracy: 0.9881666666666666
# precision: 0.9881548465514688
# recall: 0.9881313372472769
#
#  K = 5
# accuracy: 0.9886666666666667
# precision: 0.988657383232201
# recall: 0.9886482340539449
#
#  K = 7
# accuracy: 0.989
# precision: 0.9889925343654058
# recall: 0.988983661350532
#
#  K = 9
# accuracy: 0.9890833333333333
# precision: 0.9890800036202679
# recall: 0.9890676535495522
#
# In Conclusion when K values increases accuracy, precision and recall also increases.
#
# 2-) When I used non normalized Data ;
#
#  K = 1
# accuracy: 0.97775
# precision: 0.977716560440014
# recall: 0.9776958364107582
#
#  K = 3
# accuracy: 0.98825
# precision: 0.9882404225423297
# recall: 0.988217225253303
#
#  K = 5
# accuracy: 0.98875
# precision: 0.9887398079282843
# recall: 0.9887313457560725
#
#  K = 7
# accuracy: 0.9888333333333333
# precision: 0.9888283142603189
# recall: 0.9888124583311716
#
#  K = 9
# accuracy: 0.989
# precision: 0.9889955472083461
# recall: 0.9889839855441974
#
# Non normalization data has similar pattern in terms of increasment of K values.
#
# However, it can be seen that feature normalized values has bigger accuracy , precision and recall. It is more efficient that use normalized data.
#
# Error Analyse
#
# I have printed errors in every calculations.
# Reasons of these errors might be value of K. Because, when model check nearest K values majority of classes might be equal.
# For example a test case has 5 nearest class(14,14,12,13,12) it has 50% chance to predict true value. Disadvantages like these might be reason of errors.
